# %%
import sys
print("python version: ", sys.version)

import pandas as pd
print("pandas version: ", pd.__version__)

import numpy as np
print('numpy version: ', np.__version__)

import scipy as sp
print('scipy version: ', sp.__version__)

import sklearn as skl
print('sklearn version: ', skl.__version__)

import matplotlib.pyplot as plt

import seaborn as sns

import keras as ks
print('keras version: ', ks.__version__)
print('keras backend: ', ks.backend.backend())

import tensorflow as tf
print('tensorflow version: ', tf.__version__)

import theano as th
print('theano version: ', th.__version__)

import warnings
warnings.filterwarnings('ignore')


from keras import backend as K
from sklearn.metrics import confusion_matrix, precision_score, recall_score
from sklearn.metrics import roc_curve, auc, f1_score, accuracy_score, precision_recall_curve

import os
import random
# Out:
# ('python version: ', '2.7.15 |Anaconda, Inc.| (default, Dec 14 2018, 19:04:19) \n[GCC 7.3.0]')
# ('pandas version: ', u'0.23.4')
# ('numpy version: ', '1.15.4')
# ('scipy version: ', '1.1.0')
# ('sklearn version: ', '0.19.2')
# Using TensorFlow backend.
# ('keras version: ', '2.1.6')
# ('keras backend: ', u'tensorflow')
# ('tensorflow version: ', '1.10.0')
# ('theano version: ', '0.8.2')

# %%
def set_keras_backend(backend):
    if K.backend() != backend:
        os.environ['KERAS_BACKEND'] = backend
        reload(K)
        assert K.backend() == backend

set_keras_backend("tensorflow")

# %%
excel_file = r'PATH_TO_DATASET'
df = pd.DataFrame(pd.read_csv(excel_file, sep='\t'))
print(df.shape)
# Out:
# (7584, 208)

# %% [markdown]
# # Missing value means not relevant
# ### One Hot Encoding (All zero stands for NA)
# * "Mds-fall-2-6-months-to-admission", "Mds-fall-last-month-to-admission", "mds-pain-last-five-days" (Y/N/U/NA)
# * "mds-long-term-memory-ok", "mds-short-term-memory-ok", "mds-staff-assess-pain", "mds-delirium-scale", "recent-start-other-fall-risk-rx" (Y/N/NA)
# * "mds-pressure-ulcer-stage-X", (X=1, 2, 3, 4) (Y/NA)
#
# ### Label Encoding & Sin, Cos Transform (NA: (0, 0))
# * "mds-cognitive-scale":
#   - 'Independent': 0,
#   - 'Modified Independence': 1,
#   - 'Moderately Impaired': 2,
#   - 'Severely Impaired': 3
# * "mds-pain-freq-last-five-days":
#   - 'Continuous': 4,
#   - 'Frequent': 3,
#   - 'Occasional': 2,
#   - 'Rare': 1,
#   - 'Unable to respond': 0,
# * "mds-pain-intensity":
#   - 'None': 0,
#   - 'Mild': 1,
#   - 'Moderate': 2,
#   - 'Severe': 3,
#   - 'Very severe, horrible': 4
# * "Psychotropic-X": Number
# * (Added) "Psychotropic-X-Period": Number
#
#
# # Drop features
#
# * ~~"Unnamed: 51"~~,
# * ~~"pk-interaction", "pk-interaction-type"~~
# * ~~"object-drug-1", "object-drug-1-dose", "object-drug-1-effective-dose-increase", "object-drug-1-effective-dose", "interaction-1-stop-date"~~,
# * ~~"object-drug-2", "object-drug-2-dose", "object-drug-2-effective-dose-increase", "object-drug-2-effective-dose", "interaction-2-stop-date"~~
# * "ws-sudden-stop", "ws-sudden-stop-drugs", "ws-prolonged-psychotropics", "mds-toilet-prgm-atmptd"
# * "Blank-1", "Deleted-X" (X from 1 to 12), "Psychotropic-X-average-daily-dose", "Psychotropic-X-Start/End-date"
# * "Entry-discharge-type"

# %% [markdown]
# # Encode features (originally) with no missing values
#
# ### Date-related Transform
#
# * episodePeriod = episode-end-date - episode-start-date
# * stayPeriod = stay-end-date - stay-start-date
#
# ### Drop Date-related Features
#
# * "episode-start-date", "episode-end-date", "stay-start-date", "stay-end-date", "predictor-date", "projected-date"
#
# ### Binary Encoding (Y/N)
#
# * "cms-long-stay", "mds-stay-trans-short-to-long",
# * "mds-antianxiety-medication", "mds-antidepressant-medication", "mds-antipsychotic-medication", "mds-antibiotic-medication",
# * "mds-anticoagulant-medication", "mds-diuretic-medication", "mds-hypnotic-medication",
# * "mds-behavioral-symptoms", "mds-behavioral-symptoms-to-others", "mds-dehydrated", "mds-depression", "mds-fever",
# * "mds-impaired-mobility", "mds-impaired-transfer", "mds-internal-bleeding", "mds-malnutrition", "mds-no-problem-conditions",
# * "mds-vomiting", "mds-impaired-walk-in-room", "mds-impaired-walk-in-corridor", "mds-impaired-locomot-unit", "mds-impaired-locomot-other",
# * "ws-antibiotic-anticoag-coexposure",
# * "ws-psychotropic-with-not-ordered-weight-loss", "ws-diuretic-adl"
#
# ### One Hot Encoding
#
# * "race", "facility", "gender", "mds-bims-summary-ranking", "ws-meclizine-psych-coexposure",
#
# ### Drop Feature
# * "PPS-assessment", "Federal-assessment"
#
# ### Mapping
#
# * mds-pain-non-verbal {'None/Mild':0,'Moderate/Severe':1}

# %% [markdown]
# # Features need imputation
# ### One Hot Encoding
#
# 1. Binary categories (Yes/No/NA)
#    * "pneumonia", "uti", "mdro", "anemia", "septicemia", "constipation",
#    * "wound", "hyponatremia", "hyperkalemia", "embolisms",
#    * "alzheimers", "anxiety", "depression", "non-alz-dimentia",
#    * "bipolar", "parkinsons", "psychosis", "schizophrenia", "seizure", "aphasia", "emphysema",
#    * "arthritis", "ashd", "bph", "cancer", "cerebralpalsy", "stroke", "cirrhosis", "comatose",
#    * "diabetes", "dysrhythmias", "gerd", "heart-failure", "hemiplegia/hemiparesis", "hepatitis",
#    * "huntingtons", "hyperlipidemia", "hyperthyroidism", "hypothyroidism", "hypertension",
#    * "hypotension", "multiple-sclerosis", "neurogenic-bladder", "obstructive-uropathy",
#    * "osteoporosis", "paraplegia", "ptsd", "pvd", "quadriplegia", "thyroid-disorder",
#    * "tourettes", "transient-ischemic-attack", "traumatic-brain-injury", "tuberculosis", "renal-failure",
#
#    * "mds-delirium-scale", "mds-pain-medication", "mds-received-pain-tx-non-pharm ", "mds-received-prn-pain-medication",
#    * "mds-conduct-staff-assessment-mental-status", "mds-pressure-ulcer-prsnt", "conduct_bims", "acute_mental_change",
#    * "conduct_pain_assmnt", "cane_or_crutch_past_7_days", "walker_past_7_days", "wheelchair_past_7_days",
#    * "limb_prosthesis_past_7_days", "no_listed_mobility_device",
#
#
# 2. Other categories
#
#    * "marital-status":
#      - "Never Married", "Married", "Widowed", "Separated", "Divorced"
#    * "mds-entered-from":
#      - "Acute Hospital", "Psychiatric Hospital", "Another nursing home or swing bed", "Hospice", "Inpatient rehabilitation facility"
#      - "Community (private home/apt., board/care, assisted living, group home)",  "Other",
#    * "mds-excess-weight-loss":
#      - "Yes - prescribed", "Yes - not prescribed", "No or unknown"
#    * "balance_while_standing", "balance_while_walking", "balance_turning_around", "balance_toileting", "balance_bed_to_chair"
#      - "Steady at all times", "able to stabilize without assistance", "able to stabilize with assistance", "Activity did not occur"
#
# ### Label Encoding
# * "mds-urinary-incontinence"
#   - "Always continent": 0,
#   - "Occasionally incontinent": 1,
#   - "Frequently incontinent": 2,
#   - "Always incontinent": 3,
#   - "Catheter - not rated": (0, 0)
#
#
# * "cam_inattention",
# * "cam_disorganized_thought",
# * "cam_altered_conc",
# * "cam_motor_retardation"
#   - "Behavior not present": 0,
#   - "Behavior present, fluctuates": 1,
#   - "Behavior continuously present": 2,
#
#
# * "functlimit_rom_upper",
# * "functlimit_rom_lower"
#    - "No impairment": 0,
#    - "Impairment on one side": 1,
#    - "Impairment on both sides": 2
#
#
# * "does_resident_wander"
#    - "Behavior not exhibited": 0,
#    - "1 to 3 days": 1,
#    - "4 to 6 days": 2,
#    - "occurred daily": 3,

# %% [markdown]
# # Features from new dataset
# * "atc_X" (X from 1 to 5) - drop in strategy 1
# * "number_of_behavior_changes" - keep
# * "min_effective_dose_X" - drop
# * "psych_sdd_X" - drop in strategy 1

# %%
# drop feature
def drop_features(df, f):
    df.drop(f, axis=1, inplace=True)

# %%
# one hot encoding
def one_hot_encoding(df, features, categories):
    for f, c in zip(features, categories):
        df[f] = df[f].astype('category', categories=c)
    return pd.get_dummies(df, columns=features, prefix=features)

# %%
# compute date difference
def date_diff(start, end):
    return (pd.to_datetime(end) - pd.to_datetime(start)) / np.timedelta64(1, 'D')

# %%
# generate date diff features
def generate_period(df, f):
    for start, end, period in f:
        df[period] = date_diff(df[start], df[end])
        df.drop([start, end], axis=1, inplace=True)

# %%
# label encoding
def label_encoding(df, features, dictionaries):
    for f, dic in zip(features, dictionaries):
        df[f] = df[f].map(dic)

# %%
# sin&cos transform
def col_transform(df, col, mmax, mmin, df_ref=None):
    if(mmax <= mmin):
        # for test set, if max&min not set, use training set value
        if(df_ref is not None): 
            mmax = df_ref[col].max()
            mmin = df_ref[col].max()
        else:
            mmax = df[col].max()
            mmin = df[col].min()
    angle = 0.25 * np.pi * (df[col] - mmin) / (mmax - mmin) + 0.125 * np.pi
    return (np.cos(angle), np.sin(angle))

def df_transform(df, f, df_ref=None):
    for col, mmax, mmin in f:
        df[col + '_x'], df[col + '_y'] = col_transform(df, col, mmax, mmin, df_ref)
        df[col + '_x'].fillna(0, inplace=True)
        df[col + '_y'].fillna(0, inplace=True)
        df.drop(col, axis=1, inplace=True)

# %%
# train test split
from sklearn.model_selection import GroupShuffleSplit
def train_test_split(df, target, groupby, radio, random_state):
    train_idx, test_idx = GroupShuffleSplit(train_size=radio, random_state=random_state).split(df, target, df[groupby]).next()
    return df.iloc[train_idx], df.iloc[test_idx], target.iloc[train_idx], target.iloc[test_idx]

# %%
# missing data describe
def missing_summary(df):
    missing_cnt = df.isna().sum()
    missing_data = pd.concat([missing_cnt, missing_cnt/df.shape[0]], axis=1, keys=['count', 'percentage'])
    return missing_data[missing_data['percentage'] != 0].sort_values(by='percentage', ascending=False)

# %%
# Drop features
f_drop = ["Blank-1", "ws-sudden-stop", "ws-sudden-stop-drugs", "ws-prolonged-psychotropics", "mds-toilet-prgm-atmptd"] + \
         ['Deleted-%d' % i for i in range(1, 13)] + ['Psychotropic-%d' % i for i in range(1, 6)] + \
         ['Psychotropic-%d-average-daily-dose' % i for i in range(1, 6)] + ["Entry-discharge-type"]

# Missing value means not relevant
f_one_hot = ["Mds-fall-2-6-months-to-admission", "Mds-fall-last-month-to-admission", "mds-pain-last-five-days", \
             "mds-delirium-scale", "mds-long-term-memory-ok", "mds-short-term-memory-ok", "mds-staff-assess-pain", \
             "recent-start-other-fall-risk-rx"] + ["mds-pressure-ulcer-stage-%d" % i for i in range(1, 5)]
cate_one_hot = [['Yes', 'No', 'Unable to answer']] * 3 + [['Yes', 'No']] * 9

f_period = [("Psychotropic-%d-Start-date" % i, 'Psychotropic-%d-End-date' % i, 'Psychotropic-%d-Period' % i) for i in range(1, 6)]

f_label = ['mds-cognitive-scale', 'mds-pain-freq-last-five-days', 'mds-pain-intensity']
dic_label = [{'Independent': 0, 'Modified Independence': 1, 'Moderately Impaired': 2, 'Severely Impaired': 3}, \
             {'Continuous': 4, 'Frequent': 3, 'Occasional': 2, 'Rare': 1, 'Unable to respond': 0}, \
             {'None': 0, 'Mild': 1, 'Moderate': 2, 'Severe': 3, 'Very severe, horrible': 4}]

f_transform = [('mds-cognitive-scale', 3, 0), ('mds-pain-freq-last-five-days', 4, 0), ('mds-pain-intensity', 4, 0)] + \
              [('Psychotropic-%d-Period' % i, 0, 0) for i in range(1, 6)]

# %%
# Encode features (originally) with no missing values
f_drop += ["predictor-date", "projected-date", "PPS-assessment", "Federal-assessment"]

f_period += [('episode-start-date', 'episode-end-date', 'episode-period'),\
             ('stay-start-date', 'stay-end-date', 'stay-period')]

f_label += ["cms-long-stay", "mds-stay-trans-short-to-long", "mds-antianxiety-medication", \
            "mds-antidepressant-medication", "mds-antipsychotic-medication", "mds-antibiotic-medication",
            "mds-anticoagulant-medication", "mds-diuretic-medication", \
            "mds-hypnotic-medication", "mds-behavioral-symptoms", "mds-behavioral-symptoms-to-others", \
            "mds-dehydrated", "mds-depression", "mds-fever", "mds-impaired-mobility", "mds-impaired-transfer", \
            "mds-internal-bleeding", "mds-malnutrition", "mds-no-problem-conditions", "mds-vomiting", \
            "mds-impaired-walk-in-room", "mds-impaired-walk-in-corridor", "mds-impaired-locomot-unit", \
            "mds-impaired-locomot-other", "ws-antibiotic-anticoag-coexposure", \
            "ws-psychotropic-with-not-ordered-weight-loss", \
            "ws-diuretic-adl", "ws-tramadol-antidepressant-coexposure"] + ["mds-pain-non-verbal"]
dic_label += [{'Yes': 1, 'No': 0}] * 28 + [{'None/Mild':0,'Moderate/Severe':1}]

f_one_hot += ["race", "facility", "gender", "mds-bims-summary-ranking", "ws-meclizine-psych-coexposure"]
cate_one_hot += [['White', 'Black', 'Other'], \
                 ['Sugar Creek', 'Heritage Place', 'Canterbury Place', 'Senaca Place', 'Cranberry Place'], \
                 ['Female', 'Male'], ['Intact or Moderately Intact', 'Moderate Impairment'], \
                 ['No', 'meclAndPsychStartSameR', 'meclPrecedesPsychR', 'psychPrecedesMeclR', 'meclAndPsychOlderStart']]

# %%
f_drop += ["min_effective_dose_%d" % i for i in range(1, 6)] + \
          ["Psychotropic-%d-average-daily-dose" % i for i in range(1, 6)] + \
          ["psych_sdd_%d" % i for i in range(1, 6)]

# %%
# generate target
target = df['outcome-Mds-fall-since-prior-assessment'].map({'None': 0, 'Yes': 1})
dff = df.drop(['outcome-mds-fall-no-injury', 'outcome-mds-fall-minor-injury', 'outcome-mds-fall-major-injury', \
               'outcome-Mds-fall-since-prior-assessment', 'outcome-riskmaster-fall-incident'], axis=1)

# %%
# in sdd 0 means NA
for i in range(1, 6):
    df.loc[df['psych_sdd_%d' % i] == 0, 'psych_sdd_%d' % i] = np.nan

# %%
X_train, X_test, y_train, y_test = train_test_split(dff, target, 'patient-id', 0.7, 0)
print 'Total number of patients: %d' % len(df.groupby('patient-id'))
print 'Number of patients in training set: %d' % len(X_train.groupby('patient-id'))
# Out:
# Total number of patients: 3133
# Number of patients in training set: 2193

# %%
# %%time
generate_period(X_train, f_period)
label_encoding(X_train, f_label, dic_label)
X_train_original = X_train.copy() # store value range
df_transform(X_train, f_transform)
X_train = one_hot_encoding(X_train, f_one_hot, cate_one_hot)
drop_features(X_train, f_drop)
# Out:
# CPU times: user 9.5 s, sys: 92 ms, total: 9.59 s
# Wall time: 8.4 s

# %%
X_train_use = X_train.copy()

# %%
print(X_train.dtypes[X_train.dtypes == 'object'].index)
# Out:
# Index([u'marital-status', u'mds-entered-from', u'mds-pain-medication',
#        u'mds-received-pain-tx-non-pharm', u'mds-received-prn-pain-medication',
#        u'mds-excess-weight-loss', u'mds-urinary-incontinence', u'pneumonia',
#        u'uti', u'mdro', u'anemia', u'septicemia', u'constipation', u'wound',
#        u'hyponatremia', u'hyperkalemia', u'embolisms', u'alzheimers',
#        u'anxiety', u'depression', u'non-alz-dimentia', u'bipolar',
#        u'parkinsons', u'psychosis', u'schizophrenia', u'seizure', u'aphasia',
#        u'emphysema', u'arthritis', u'ashd', u'bph', u'cancer',
#        u'cerebralpalsy', u'stroke', u'cirrhosis', u'comatose', u'diabetes',
#        u'dysrhythmias', u'gerd', u'heart-failure', u'hemiplegia/hemiparesis',
#        u'hepatitis', u'huntingtons', u'hyperlipidemia', u'hyperthyroidism',
#        u'hypothyroidism', u'hypertension', u'hypotension',
#        u'multiple-sclerosis', u'neurogenic-bladder', u'obstructive-uropathy',
#        u'osteoporosis', u'paraplegia', u'ptsd', u'pvd', u'quadriplegia',
#        u'thyroid-disorder', u'tourettes', u'transient-ischemic-attack',
#        u'traumatic-brain-injury', u'tuberculosis', u'renal-failure',
#        u'mds-conduct-staff-assessment-mental-status',
#        u'mds-pressure-ulcer-prsnt', u'conduct_bims', u'cam_inattention',
#        u'cam_disorganized_thought', u'cam_altered_conc',
#        u'cam_motor_retardation', u'acute_mental_change',
#        u'conduct_pain_assmnt', u'balance_while_standing',
#        u'balance_while_walking', u'balance_turning_around',
#        u'balance_toileting', u'balance_bed_to_chair', u'functlimit_rom_upper',
#        u'functlimit_rom_lower', u'cane_or_crutch_past_7_days',
#        u'walker_past_7_days', u'wheelchair_past_7_days',
#        u'limb_prosthesis_past_7_days', u'no_listed_mobility_device',
#        u'does_resident_wander', u'atc_1', u'atc_2', u'atc_3', u'atc_4',
#        u'atc_5'],
#       dtype='object')

# %%
missing_summary(X_train_use)
# Out:
#                                             count  percentage
# atc_5                                        5276    0.993410
# atc_4                                        5151    0.969874
# atc_3                                        4763    0.896818
# atc_2                                        3758    0.707588
# atc_1                                        2016    0.379590
# mds-conduct-staff-assessment-mental-status   1105    0.208059
# functlimit_rom_upper                          320    0.060252
# marital-status                                317    0.059687
# functlimit_rom_lower                          316    0.059499
# balance_bed_to_chair                          304    0.057240
# balance_toileting                             293    0.055169
# balance_turning_around                        288    0.054227
# balance_while_walking                         288    0.054227
# balance_while_standing                        286    0.053850
# cam_disorganized_thought                      139    0.026172
# cam_inattention                               125    0.023536
# cam_altered_conc                              119    0.022406
# cam_motor_retardation                         119    0.022406
# mdro                                          111    0.020900
# pneumonia                                     111    0.020900
# uti                                           111    0.020900
# wound                                         111    0.020900
# hyperkalemia                                  111    0.020900
# anemia                                        111    0.020900
# septicemia                                    111    0.020900
# constipation                                  111    0.020900
# hyponatremia                                  111    0.020900
# embolisms                                     111    0.020900
# mds-received-pain-tx-non-pharm                102    0.019205
# conduct_pain_assmnt                           101    0.019017
# ...                                           ...         ...
# seizure                                        43    0.008096
# psychosis                                      43    0.008096
# neurogenic-bladder                             43    0.008096
# parkinsons                                     43    0.008096
# bipolar                                        43    0.008096
# non-alz-dimentia                               43    0.008096
# depression                                     43    0.008096
# anxiety                                        43    0.008096
# alzheimers                                     43    0.008096
# cancer                                         43    0.008096
# cerebralpalsy                                  43    0.008096
# stroke                                         43    0.008096
# hemiplegia/hemiparesis                         43    0.008096
# hypotension                                    43    0.008096
# hypertension                                   43    0.008096
# hypothyroidism                                 43    0.008096
# hyperlipidemia                                 43    0.008096
# huntingtons                                    43    0.008096
# cirrhosis                                      43    0.008096
# hepatitis                                      43    0.008096
# heart-failure                                  43    0.008096
# gerd                                           43    0.008096
# dysrhythmias                                   43    0.008096
# diabetes                                       43    0.008096
# comatose                                       43    0.008096
# hyperthyroidism                                43    0.008096
# conduct_bims                                   33    0.006214
# does_resident_wander                           33    0.006214
# mds-entered-from                               25    0.004707
# mds-excess-weight-loss                          3    0.000565
#
# [89 rows x 2 columns]

# %%
# %%time
generate_period(X_test, f_period)
label_encoding(X_test, f_label, dic_label)
df_transform(X_test, f_transform, X_train_original)
X_test = one_hot_encoding(X_test, f_one_hot, cate_one_hot)
drop_features(X_test, f_drop)
# Out:
# CPU times: user 7.44 s, sys: 16 ms, total: 7.45 s
# Wall time: 7.45 s

# %%
X_test_use = X_test.copy()

# %%
print(X_train.dtypes[X_train.dtypes == 'object'].index)
# Out:
# Index([u'marital-status', u'mds-entered-from', u'mds-pain-medication',
#        u'mds-received-pain-tx-non-pharm', u'mds-received-prn-pain-medication',
#        u'mds-excess-weight-loss', u'mds-urinary-incontinence', u'pneumonia',
#        u'uti', u'mdro', u'anemia', u'septicemia', u'constipation', u'wound',
#        u'hyponatremia', u'hyperkalemia', u'embolisms', u'alzheimers',
#        u'anxiety', u'depression', u'non-alz-dimentia', u'bipolar',
#        u'parkinsons', u'psychosis', u'schizophrenia', u'seizure', u'aphasia',
#        u'emphysema', u'arthritis', u'ashd', u'bph', u'cancer',
#        u'cerebralpalsy', u'stroke', u'cirrhosis', u'comatose', u'diabetes',
#        u'dysrhythmias', u'gerd', u'heart-failure', u'hemiplegia/hemiparesis',
#        u'hepatitis', u'huntingtons', u'hyperlipidemia', u'hyperthyroidism',
#        u'hypothyroidism', u'hypertension', u'hypotension',
#        u'multiple-sclerosis', u'neurogenic-bladder', u'obstructive-uropathy',
#        u'osteoporosis', u'paraplegia', u'ptsd', u'pvd', u'quadriplegia',
#        u'thyroid-disorder', u'tourettes', u'transient-ischemic-attack',
#        u'traumatic-brain-injury', u'tuberculosis', u'renal-failure',
#        u'mds-conduct-staff-assessment-mental-status',
#        u'mds-pressure-ulcer-prsnt', u'conduct_bims', u'cam_inattention',
#        u'cam_disorganized_thought', u'cam_altered_conc',
#        u'cam_motor_retardation', u'acute_mental_change',
#        u'conduct_pain_assmnt', u'balance_while_standing',
#        u'balance_while_walking', u'balance_turning_around',
#        u'balance_toileting', u'balance_bed_to_chair', u'functlimit_rom_upper',
#        u'functlimit_rom_lower', u'cane_or_crutch_past_7_days',
#        u'walker_past_7_days', u'wheelchair_past_7_days',
#        u'limb_prosthesis_past_7_days', u'no_listed_mobility_device',
#        u'does_resident_wander', u'atc_1', u'atc_2', u'atc_3', u'atc_4',
#        u'atc_5'],
#       dtype='object')

# %%
missing_summary(X_test_use)
# Out:
#                                             count  percentage
# atc_5                                        1503    0.994048
# atc_4                                        1467    0.970238
# atc_3                                        1348    0.891534
# atc_2                                        1068    0.706349
# atc_1                                         579    0.382937
# mds-conduct-staff-assessment-mental-status    294    0.194444
# marital-status                                101    0.066799
# functlimit_rom_lower                           90    0.059524
# functlimit_rom_upper                           90    0.059524
# balance_bed_to_chair                           88    0.058201
# balance_turning_around                         86    0.056878
# balance_while_standing                         86    0.056878
# balance_while_walking                          86    0.056878
# balance_toileting                              85    0.056217
# cam_disorganized_thought                       36    0.023810
# cam_inattention                                30    0.019841
# cam_altered_conc                               29    0.019180
# cam_motor_retardation                          29    0.019180
# conduct_pain_assmnt                            27    0.017857
# uti                                            26    0.017196
# acute_mental_change                            26    0.017196
# pneumonia                                      26    0.017196
# septicemia                                     26    0.017196
# hyponatremia                                   26    0.017196
# mdro                                           26    0.017196
# anemia                                         26    0.017196
# constipation                                   26    0.017196
# wound                                          26    0.017196
# embolisms                                      26    0.017196
# hyperkalemia                                   26    0.017196
# ...                                           ...         ...
# seizure                                        14    0.009259
# psychosis                                      14    0.009259
# neurogenic-bladder                             14    0.009259
# parkinsons                                     14    0.009259
# bipolar                                        14    0.009259
# non-alz-dimentia                               14    0.009259
# depression                                     14    0.009259
# anxiety                                        14    0.009259
# alzheimers                                     14    0.009259
# cancer                                         14    0.009259
# cerebralpalsy                                  14    0.009259
# stroke                                         14    0.009259
# hemiplegia/hemiparesis                         14    0.009259
# hypotension                                    14    0.009259
# hypertension                                   14    0.009259
# hypothyroidism                                 14    0.009259
# hyperlipidemia                                 14    0.009259
# huntingtons                                    14    0.009259
# cirrhosis                                      14    0.009259
# hepatitis                                      14    0.009259
# heart-failure                                  14    0.009259
# gerd                                           14    0.009259
# dysrhythmias                                   14    0.009259
# diabetes                                       14    0.009259
# comatose                                       14    0.009259
# hyperthyroidism                                14    0.009259
# mds-entered-from                               12    0.007937
# does_resident_wander                            8    0.005291
# conduct_bims                                    7    0.004630
# mds-excess-weight-loss                          2    0.001323
#
# [89 rows x 2 columns]

# %%
X_train_use.shape
# Out:
# (5311, 189)

# %%
X_test_use.shape
# Out:
# (1512, 189)

# %% [markdown]
# # Experiment: Use non-missing values to train model
# ### Prepare Test Set Features

# %%
idx = missing_summary(X_train_use).index.tolist()
X_train_use.drop(columns=idx, axis=1, inplace=True)
X_test_use.drop(columns=idx, axis=1, inplace=True)

# %%
X_train_use.shape
# Out:
# (5311, 100)

# %%
X_test_use.shape
# Out:
# (1512, 100)

# %% [markdown]
# ### RNN

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout
from numpy.random import seed
from tensorflow import set_random_seed
from copy import deepcopy

# %%
def scaler_transform(X_train_use, X_test_use):    
    scaler = MinMaxScaler(feature_range=(0, 1)).fit(X_train_use.drop('patient-id', axis=1))
    X_train_transformed = pd.DataFrame(scaler.transform(X_train_use.drop('patient-id', axis=1)), \
                                       columns=X_train_use.columns[1:], index=X_train_use.index)                                   
    X_train_transformed['patient-id'] = X_train_use['patient-id']
    X_test_transformed = pd.DataFrame(scaler.transform(X_test_use.drop('patient-id', axis=1)), \
                                       columns=X_test_use.columns[1:], index=X_test_use.index) 
    X_test_transformed['patient-id'] = X_test_use['patient-id']
    return X_train_transformed, X_test_transformed

# %%
def generate_nested_list(X, Y):
    X = X.copy()
    Y = Y.copy()
    x_list, y_list = [], [] 
    x1, x2 = [], []
    pids = X['patient-id'].unique()
    for pid in pids:
        df = Y[X[X['patient-id']==pid].index]
        if(df.shape[0] == 1):
            x1.append(pd.Series([0]))
            x2.append(pd.Series([0]))
        else:
            # input 1=(1, 0), 0=(0, 1), NA=(0, 0)
            x1.append(pd.Series([0]))
            x1.append(df[:-1])
            x2.append(pd.Series([0]))
            x2.append(df[:-1].map({0: 1, 1: 0}))
    X['input_outcome_x'] = pd.Series(pd.concat(x1, ignore_index=True).tolist(), index=X.index)
    X['input_outcome_y'] = pd.Series(pd.concat(x2, ignore_index=True).tolist(), index=X.index)
    for pid in pids:
        df = X[X['patient-id']==pid]
        y_list.append(Y[df.index].values)
        x_list.append([record for record in df.drop('patient-id', axis=1).values])
    return x_list, y_list

# %%
def mygenerator(x_list, y_list=None):
    if(y_list is not None):
        while True:
            for x, y in zip(x_list, y_list):
                yield np.array(x).reshape((len(x), 1, x[0].shape[0])), y
    else:
        while True:
            for x in x_list:
                yield np.array(x).reshape((len(x), 1, x[0].shape[0]))

# %%
def fit_model(model, epoch, X_train, y_train, X_valid=None, y_valid=None, verbose=0):
    if(verbose == 0):
        model.fit_generator(mygenerator(X_train, y_train), steps_per_epoch=len(X_train), epochs=epoch, verbose=0)
    else:
        history = model.fit_generator(mygenerator(X_train, y_train), steps_per_epoch=len(X_train), \
                                      validation_data=mygenerator(X_valid, y_valid), validation_steps=len(X_valid), \
                                      epochs=epoch, verbose=verbose)
        plot_history(history)
    return history

# %%
def plot_roc_curve(fpr, tpr):
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % auc(fpr, tpr))
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc="lower right")
    plt.show()

# %%
def plot_history(history, loss=None, val_loss=None):
    if(history is not None):
        loss = history.history['loss']
        val_loss = history.history['val_loss']
    plt.figure()
    plt.plot(loss)
    plt.plot(val_loss)
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()

# %%
from sklearn.model_selection import GroupKFold
def kfold_validation(unit, ratio, epoch, X, y, groupby, k=5, verbose=0):
    auroc_list = []
    for train_idx, valid_idx in GroupKFold(n_splits=5).split(X, y, X[groupby]):
        X_train, X_valid, y_train, y_valid = X.iloc[train_idx], X.iloc[valid_idx], y.iloc[train_idx], y.iloc[valid_idx]
        X_train, y_train = generate_nested_list(X_train, y_train)
        X_valid, y_valid = generate_nested_list(X_valid, y_valid)
        seed(1)
        set_random_seed(2)
        model = build_model(unit, ratio, 1, X_train[0][0].shape[0])
        if (verbose == 0):
            fit_model(model, epoch, X_train, y_train)
        else:
            fit_model(model, epoch, X_train, y_train, X_valid, y_valid, verbose)
        y_predict = model.predict_generator(mygenerator(X_valid), steps=len(X_valid))
        y_predict = np.concatenate(y_predict)
        y_true = np.concatenate(y_valid)
        auroc_list.append(auroc(y_predict, y_true))
    return auroc_list

# %%
def auroc(y_predict, y_true, plot=False):
    fpr, tpr, thresholds = roc_curve(y_true, y_predict, pos_label=1)    
    if(plot):
        plot_roc_curve(fpr, tpr)
    return auc(fpr, tpr)

# %%
def find_best_f1(y_predict, y_true):
    fpr, tpr, thresholds = roc_curve(y_true, y_predict, pos_label=1) 
    max_f1, th = 0, 0
    for threshold in thresholds:
        f1 = f1_score(y_true, y_predict > threshold)
        if(f1 > max_f1):
            max_f1 = f1
            th = threshold
    return max_f1, th

# %%
def other_metrics(y_predict, y_true, threshold):
    y_threshold = y_predict > threshold
    tn, fp, fn, tp = confusion_matrix(y_true, y_threshold).ravel()
    return precision_score(y_true, y_threshold), recall_score(y_true, y_threshold),\
            accuracy_score(y_true, y_threshold), float(tn) / (tn + fp)

# %%
X_train_transformed, X_test_transformed = scaler_transform(X_train_use, X_test_use)

# %%
# %%time
X_train_list, y_train_list = generate_nested_list(X_train_transformed, y_train)
X_test_list, y_test_list = generate_nested_list(X_test_transformed, y_test)

# %%
from keras import regularizers
from keras.optimizers import Adagrad, Adadelta
def build_model(cell_size, dropout_ratio, n_timesteps, n_dimensions):
    model = Sequential()
#     model.add(LSTM(cell_size, input_shape=(n_timesteps, n_dimensions), recurrent_dropout=dropout_ratio))
    model.add(LSTM(cell_size, input_shape=(n_timesteps, n_dimensions), recurrent_dropout=dropout_ratio, dropout=0.5))
#     model.add(LSTM(cell_size, input_shape=(n_timesteps, n_dimensions), recurrent_dropout=0.4, recurrent_regularizer=regularizers.l2(dropout_ratio)))
#     model.add(LSTM(cell_size, input_shape=(n_timesteps, n_dimensions)))
#     model.add(GRU(cell_size, input_shape=(n_timesteps, n_dimensions), recurrent_dropout=dropout_ratio))
#     model.add(Dropout(dropout_ratio))
    model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer=Adagrad(lr=0.02), metrics=['binary_accuracy'])
    model.compile(loss='binary_crossentropy', optimizer='adagrad', metrics=['binary_accuracy'])
    return model

# %%
# %%time
seed(1)
set_random_seed(2)
auroc_list = []
precision_list = []
recall_list = []
accuracy_list = []
specificity_list = []
f1_list = []
th_list = []
for i in range(0,1):
    model = build_model(32, 0.5, 1, X_train_list[0][0].shape[0])
    history = fit_model(model, 180, X_train_list, y_train_list, X_test_list, y_test_list, verbose=1)
    y_predict = model.predict_generator(mygenerator(X_test_list), steps=len(X_test_list))
    y_predict = np.concatenate(y_predict)
    y_true = np.concatenate(y_test_list)
    auroc_list.append(auroc(y_predict, y_true))
    f1, th = find_best_f1(y_predict, y_true)
    f1_list.append(f1)
    th_list.append(th)
    precision, recall, accuracy, specificity = other_metrics(y_predict, y_true, th)
    precision_list.append(precision)
    recall_list.append(recall)
    accuracy_list.append(accuracy)
    specificity_list.append(specificity)
print('avg auroc: ', np.mean(auroc_list))
print('avg precision: ', np.mean(precision_list))
print('avg recall: ', np.mean(recall_list))
print('avg accuracy: ', np.mean(accuracy_list))
print('avg specificity: ', np.mean(specificity_list))
print('avg f1: ', np.mean(f1_list));
print('auroc: ', auroc_list)
print('precision: ', precision_list)
print('recall: ', recall_list)
print('accuracy: ', accuracy_list)
print('specificity: ', specificity_list)
print('f1: ', f1_list);
print('threshold: ', th_list)
# Out:
# Epoch 1/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3786 - binary_accuracy: 0.8707 - val_loss: 0.4663 - val_binary_accuracy: 0.8128
# Epoch 2/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3628 - binary_accuracy: 0.8714 - val_loss: 0.4614 - val_binary_accuracy: 0.8128
# Epoch 3/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3610 - binary_accuracy: 0.8714 - val_loss: 0.4596 - val_binary_accuracy: 0.8128
# Epoch 4/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3583 - binary_accuracy: 0.8716 - val_loss: 0.4573 - val_binary_accuracy: 0.8128
# Epoch 5/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3580 - binary_accuracy: 0.8717 - val_loss: 0.4572 - val_binary_accuracy: 0.8128
# Epoch 6/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3550 - binary_accuracy: 0.8710 - val_loss: 0.4562 - val_binary_accuracy: 0.8128
# Epoch 7/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3519 - binary_accuracy: 0.8711 - val_loss: 0.4558 - val_binary_accuracy: 0.8128
# Epoch 8/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3550 - binary_accuracy: 0.8713 - val_loss: 0.4550 - val_binary_accuracy: 0.8128
# Epoch 9/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3551 - binary_accuracy: 0.8707 - val_loss: 0.4541 - val_binary_accuracy: 0.8128
# Epoch 10/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3529 - binary_accuracy: 0.8715 - val_loss: 0.4550 - val_binary_accuracy: 0.8128
# Epoch 11/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3531 - binary_accuracy: 0.8712 - val_loss: 0.4542 - val_binary_accuracy: 0.8128
# Epoch 12/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3520 - binary_accuracy: 0.8718 - val_loss: 0.4530 - val_binary_accuracy: 0.8128
# Epoch 13/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3535 - binary_accuracy: 0.8713 - val_loss: 0.4526 - val_binary_accuracy: 0.8128
# Epoch 14/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3520 - binary_accuracy: 0.8720 - val_loss: 0.4523 - val_binary_accuracy: 0.8128
# Epoch 15/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3494 - binary_accuracy: 0.8716 - val_loss: 0.4517 - val_binary_accuracy: 0.8128
# Epoch 16/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3499 - binary_accuracy: 0.8710 - val_loss: 0.4514 - val_binary_accuracy: 0.8128
# Epoch 17/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3531 - binary_accuracy: 0.8720 - val_loss: 0.4517 - val_binary_accuracy: 0.8128
# Epoch 18/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3504 - binary_accuracy: 0.8713 - val_loss: 0.4506 - val_binary_accuracy: 0.8128
# Epoch 19/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3510 - binary_accuracy: 0.8718 - val_loss: 0.4502 - val_binary_accuracy: 0.8128
# Epoch 20/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3537 - binary_accuracy: 0.8717 - val_loss: 0.4496 - val_binary_accuracy: 0.8128
# Epoch 21/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3482 - binary_accuracy: 0.8717 - val_loss: 0.4496 - val_binary_accuracy: 0.8128
# Epoch 22/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3507 - binary_accuracy: 0.8723 - val_loss: 0.4492 - val_binary_accuracy: 0.8128
# Epoch 23/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3505 - binary_accuracy: 0.8716 - val_loss: 0.4482 - val_binary_accuracy: 0.8128
# Epoch 24/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3503 - binary_accuracy: 0.8712 - val_loss: 0.4486 - val_binary_accuracy: 0.8128
# Epoch 25/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3499 - binary_accuracy: 0.8726 - val_loss: 0.4488 - val_binary_accuracy: 0.8128
# Epoch 26/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3483 - binary_accuracy: 0.8722 - val_loss: 0.4484 - val_binary_accuracy: 0.8128
# Epoch 27/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3483 - binary_accuracy: 0.8707 - val_loss: 0.4483 - val_binary_accuracy: 0.8128
# Epoch 28/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3481 - binary_accuracy: 0.8707 - val_loss: 0.4484 - val_binary_accuracy: 0.8128
# Epoch 29/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3468 - binary_accuracy: 0.8719 - val_loss: 0.4484 - val_binary_accuracy: 0.8128
# Epoch 30/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3460 - binary_accuracy: 0.8724 - val_loss: 0.4480 - val_binary_accuracy: 0.8128
# Epoch 31/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3507 - binary_accuracy: 0.8720 - val_loss: 0.4473 - val_binary_accuracy: 0.8128
# Epoch 32/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3487 - binary_accuracy: 0.8719 - val_loss: 0.4477 - val_binary_accuracy: 0.8128
# Epoch 33/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3480 - binary_accuracy: 0.8710 - val_loss: 0.4475 - val_binary_accuracy: 0.8128
# Epoch 34/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3480 - binary_accuracy: 0.8714 - val_loss: 0.4465 - val_binary_accuracy: 0.8128
# Epoch 35/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3476 - binary_accuracy: 0.8721 - val_loss: 0.4469 - val_binary_accuracy: 0.8128
# Epoch 36/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3476 - binary_accuracy: 0.8714 - val_loss: 0.4471 - val_binary_accuracy: 0.8128
# Epoch 37/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3464 - binary_accuracy: 0.8719 - val_loss: 0.4470 - val_binary_accuracy: 0.8128
# Epoch 38/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3461 - binary_accuracy: 0.8726 - val_loss: 0.4465 - val_binary_accuracy: 0.8128
# Epoch 39/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3464 - binary_accuracy: 0.8717 - val_loss: 0.4465 - val_binary_accuracy: 0.8128
# Epoch 40/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3464 - binary_accuracy: 0.8724 - val_loss: 0.4466 - val_binary_accuracy: 0.8128
# Epoch 41/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3472 - binary_accuracy: 0.8711 - val_loss: 0.4467 - val_binary_accuracy: 0.8128
# Epoch 42/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3500 - binary_accuracy: 0.8702 - val_loss: 0.4456 - val_binary_accuracy: 0.8128
# Epoch 43/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3458 - binary_accuracy: 0.8716 - val_loss: 0.4454 - val_binary_accuracy: 0.8128
# Epoch 44/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3442 - binary_accuracy: 0.8713 - val_loss: 0.4455 - val_binary_accuracy: 0.8128
# Epoch 45/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3462 - binary_accuracy: 0.8727 - val_loss: 0.4449 - val_binary_accuracy: 0.8128
# Epoch 46/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3438 - binary_accuracy: 0.8719 - val_loss: 0.4454 - val_binary_accuracy: 0.8128
# Epoch 47/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3459 - binary_accuracy: 0.8709 - val_loss: 0.4453 - val_binary_accuracy: 0.8128
# Epoch 48/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3465 - binary_accuracy: 0.8714 - val_loss: 0.4451 - val_binary_accuracy: 0.8128
# Epoch 49/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3441 - binary_accuracy: 0.8722 - val_loss: 0.4452 - val_binary_accuracy: 0.8122
# Epoch 50/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3471 - binary_accuracy: 0.8706 - val_loss: 0.4452 - val_binary_accuracy: 0.8135
# Epoch 51/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3458 - binary_accuracy: 0.8718 - val_loss: 0.4446 - val_binary_accuracy: 0.8128
# Epoch 52/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3454 - binary_accuracy: 0.8723 - val_loss: 0.4449 - val_binary_accuracy: 0.8135
# Epoch 53/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3458 - binary_accuracy: 0.8721 - val_loss: 0.4444 - val_binary_accuracy: 0.8128
# Epoch 54/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3440 - binary_accuracy: 0.8733 - val_loss: 0.4443 - val_binary_accuracy: 0.8128
# Epoch 55/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3464 - binary_accuracy: 0.8713 - val_loss: 0.4445 - val_binary_accuracy: 0.8128
# Epoch 56/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3470 - binary_accuracy: 0.8715 - val_loss: 0.4442 - val_binary_accuracy: 0.8128
# Epoch 57/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3444 - binary_accuracy: 0.8708 - val_loss: 0.4445 - val_binary_accuracy: 0.8128
# Epoch 58/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3434 - binary_accuracy: 0.8727 - val_loss: 0.4446 - val_binary_accuracy: 0.8128
# Epoch 59/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3445 - binary_accuracy: 0.8729 - val_loss: 0.4445 - val_binary_accuracy: 0.8128
# Epoch 60/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3406 - binary_accuracy: 0.8728 - val_loss: 0.4446 - val_binary_accuracy: 0.8128
# Epoch 61/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3449 - binary_accuracy: 0.8724 - val_loss: 0.4445 - val_binary_accuracy: 0.8128
# Epoch 62/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3417 - binary_accuracy: 0.8725 - val_loss: 0.4443 - val_binary_accuracy: 0.8128
# Epoch 63/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3452 - binary_accuracy: 0.8704 - val_loss: 0.4441 - val_binary_accuracy: 0.8128
# Epoch 64/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3453 - binary_accuracy: 0.8727 - val_loss: 0.4440 - val_binary_accuracy: 0.8128
# Epoch 65/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3446 - binary_accuracy: 0.8727 - val_loss: 0.4437 - val_binary_accuracy: 0.8128
# Epoch 66/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3440 - binary_accuracy: 0.8712 - val_loss: 0.4434 - val_binary_accuracy: 0.8128
# Epoch 67/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3437 - binary_accuracy: 0.8716 - val_loss: 0.4433 - val_binary_accuracy: 0.8128
# Epoch 68/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3440 - binary_accuracy: 0.8727 - val_loss: 0.4432 - val_binary_accuracy: 0.8128
# Epoch 69/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3458 - binary_accuracy: 0.8714 - val_loss: 0.4428 - val_binary_accuracy: 0.8128
# Epoch 70/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3432 - binary_accuracy: 0.8731 - val_loss: 0.4428 - val_binary_accuracy: 0.8128
# Epoch 71/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3440 - binary_accuracy: 0.8708 - val_loss: 0.4424 - val_binary_accuracy: 0.8128
# Epoch 72/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3418 - binary_accuracy: 0.8721 - val_loss: 0.4426 - val_binary_accuracy: 0.8128
# Epoch 73/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3456 - binary_accuracy: 0.8718 - val_loss: 0.4424 - val_binary_accuracy: 0.8128
# Epoch 74/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3431 - binary_accuracy: 0.8723 - val_loss: 0.4423 - val_binary_accuracy: 0.8128
# Epoch 75/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3448 - binary_accuracy: 0.8729 - val_loss: 0.4424 - val_binary_accuracy: 0.8128
# Epoch 76/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3417 - binary_accuracy: 0.8720 - val_loss: 0.4422 - val_binary_accuracy: 0.8128
# Epoch 77/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3446 - binary_accuracy: 0.8718 - val_loss: 0.4420 - val_binary_accuracy: 0.8128
# Epoch 78/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3457 - binary_accuracy: 0.8716 - val_loss: 0.4422 - val_binary_accuracy: 0.8128
# Epoch 79/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3441 - binary_accuracy: 0.8726 - val_loss: 0.4419 - val_binary_accuracy: 0.8128
# Epoch 80/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3423 - binary_accuracy: 0.8722 - val_loss: 0.4419 - val_binary_accuracy: 0.8128
# Epoch 81/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3443 - binary_accuracy: 0.8732 - val_loss: 0.4422 - val_binary_accuracy: 0.8128
# Epoch 82/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3458 - binary_accuracy: 0.8708 - val_loss: 0.4423 - val_binary_accuracy: 0.8128
# Epoch 83/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3459 - binary_accuracy: 0.8720 - val_loss: 0.4417 - val_binary_accuracy: 0.8128
# Epoch 84/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3426 - binary_accuracy: 0.8713 - val_loss: 0.4420 - val_binary_accuracy: 0.8128
# Epoch 85/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3443 - binary_accuracy: 0.8721 - val_loss: 0.4424 - val_binary_accuracy: 0.8122
# Epoch 86/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3435 - binary_accuracy: 0.8708 - val_loss: 0.4424 - val_binary_accuracy: 0.8122
# Epoch 87/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3401 - binary_accuracy: 0.8738 - val_loss: 0.4425 - val_binary_accuracy: 0.8122
# Epoch 88/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3438 - binary_accuracy: 0.8716 - val_loss: 0.4421 - val_binary_accuracy: 0.8122
# Epoch 89/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3418 - binary_accuracy: 0.8708 - val_loss: 0.4423 - val_binary_accuracy: 0.8122
# Epoch 90/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3456 - binary_accuracy: 0.8711 - val_loss: 0.4417 - val_binary_accuracy: 0.8122
# Epoch 91/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3386 - binary_accuracy: 0.8722 - val_loss: 0.4417 - val_binary_accuracy: 0.8128
# Epoch 92/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3436 - binary_accuracy: 0.8732 - val_loss: 0.4420 - val_binary_accuracy: 0.8122
# Epoch 93/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3420 - binary_accuracy: 0.8727 - val_loss: 0.4413 - val_binary_accuracy: 0.8128
# Epoch 94/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3418 - binary_accuracy: 0.8733 - val_loss: 0.4416 - val_binary_accuracy: 0.8128
# Epoch 95/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3436 - binary_accuracy: 0.8723 - val_loss: 0.4417 - val_binary_accuracy: 0.8128
# Epoch 96/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3409 - binary_accuracy: 0.8724 - val_loss: 0.4414 - val_binary_accuracy: 0.8128
# Epoch 97/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3447 - binary_accuracy: 0.8726 - val_loss: 0.4411 - val_binary_accuracy: 0.8128
# Epoch 98/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3429 - binary_accuracy: 0.8716 - val_loss: 0.4409 - val_binary_accuracy: 0.8128
# Epoch 99/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3424 - binary_accuracy: 0.8719 - val_loss: 0.4409 - val_binary_accuracy: 0.8128
# Epoch 100/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3449 - binary_accuracy: 0.8723 - val_loss: 0.4406 - val_binary_accuracy: 0.8128
# Epoch 101/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3426 - binary_accuracy: 0.8716 - val_loss: 0.4410 - val_binary_accuracy: 0.8128
# Epoch 102/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3391 - binary_accuracy: 0.8731 - val_loss: 0.4412 - val_binary_accuracy: 0.8128
# Epoch 103/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3428 - binary_accuracy: 0.8710 - val_loss: 0.4411 - val_binary_accuracy: 0.8128
# Epoch 104/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3385 - binary_accuracy: 0.8724 - val_loss: 0.4413 - val_binary_accuracy: 0.8128
# Epoch 105/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3426 - binary_accuracy: 0.8721 - val_loss: 0.4406 - val_binary_accuracy: 0.8128
# Epoch 106/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3425 - binary_accuracy: 0.8718 - val_loss: 0.4407 - val_binary_accuracy: 0.8128
# Epoch 107/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3416 - binary_accuracy: 0.8713 - val_loss: 0.4409 - val_binary_accuracy: 0.8128
# Epoch 108/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3440 - binary_accuracy: 0.8726 - val_loss: 0.4406 - val_binary_accuracy: 0.8128
# Epoch 109/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3435 - binary_accuracy: 0.8712 - val_loss: 0.4406 - val_binary_accuracy: 0.8128
# Epoch 110/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3421 - binary_accuracy: 0.8722 - val_loss: 0.4408 - val_binary_accuracy: 0.8122
# Epoch 111/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3426 - binary_accuracy: 0.8715 - val_loss: 0.4410 - val_binary_accuracy: 0.8122
# Epoch 112/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3422 - binary_accuracy: 0.8728 - val_loss: 0.4409 - val_binary_accuracy: 0.8122
# Epoch 113/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3416 - binary_accuracy: 0.8740 - val_loss: 0.4408 - val_binary_accuracy: 0.8122
# Epoch 114/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3404 - binary_accuracy: 0.8723 - val_loss: 0.4409 - val_binary_accuracy: 0.8122
# Epoch 115/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3422 - binary_accuracy: 0.8714 - val_loss: 0.4407 - val_binary_accuracy: 0.8128
# Epoch 116/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3403 - binary_accuracy: 0.8722 - val_loss: 0.4408 - val_binary_accuracy: 0.8122
# Epoch 117/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3421 - binary_accuracy: 0.8736 - val_loss: 0.4409 - val_binary_accuracy: 0.8122
# Epoch 118/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3434 - binary_accuracy: 0.8716 - val_loss: 0.4407 - val_binary_accuracy: 0.8122
# Epoch 119/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3392 - binary_accuracy: 0.8732 - val_loss: 0.4407 - val_binary_accuracy: 0.8128
# Epoch 120/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3430 - binary_accuracy: 0.8709 - val_loss: 0.4407 - val_binary_accuracy: 0.8128
# Epoch 121/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3420 - binary_accuracy: 0.8727 - val_loss: 0.4407 - val_binary_accuracy: 0.8128
# Epoch 122/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3409 - binary_accuracy: 0.8708 - val_loss: 0.4407 - val_binary_accuracy: 0.8128
# Epoch 123/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3373 - binary_accuracy: 0.8717 - val_loss: 0.4410 - val_binary_accuracy: 0.8128
# Epoch 124/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3408 - binary_accuracy: 0.8724 - val_loss: 0.4410 - val_binary_accuracy: 0.8128
# Epoch 125/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3393 - binary_accuracy: 0.8723 - val_loss: 0.4408 - val_binary_accuracy: 0.8135
# Epoch 126/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3383 - binary_accuracy: 0.8732 - val_loss: 0.4405 - val_binary_accuracy: 0.8135
# Epoch 127/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3430 - binary_accuracy: 0.8720 - val_loss: 0.4400 - val_binary_accuracy: 0.8135
# Epoch 128/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3403 - binary_accuracy: 0.8743 - val_loss: 0.4406 - val_binary_accuracy: 0.8135
# Epoch 129/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3386 - binary_accuracy: 0.8719 - val_loss: 0.4407 - val_binary_accuracy: 0.8135
# Epoch 130/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3396 - binary_accuracy: 0.8727 - val_loss: 0.4406 - val_binary_accuracy: 0.8135
# Epoch 131/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3445 - binary_accuracy: 0.8712 - val_loss: 0.4403 - val_binary_accuracy: 0.8135
# Epoch 132/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3419 - binary_accuracy: 0.8715 - val_loss: 0.4401 - val_binary_accuracy: 0.8135
# Epoch 133/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3433 - binary_accuracy: 0.8726 - val_loss: 0.4398 - val_binary_accuracy: 0.8135
# Epoch 134/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3394 - binary_accuracy: 0.8719 - val_loss: 0.4402 - val_binary_accuracy: 0.8135
# Epoch 135/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3431 - binary_accuracy: 0.8714 - val_loss: 0.4399 - val_binary_accuracy: 0.8135
# Epoch 136/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3414 - binary_accuracy: 0.8725 - val_loss: 0.4398 - val_binary_accuracy: 0.8135
# Epoch 137/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3395 - binary_accuracy: 0.8720 - val_loss: 0.4400 - val_binary_accuracy: 0.8135
# Epoch 138/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3417 - binary_accuracy: 0.8721 - val_loss: 0.4403 - val_binary_accuracy: 0.8135
# Epoch 139/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3402 - binary_accuracy: 0.8720 - val_loss: 0.4402 - val_binary_accuracy: 0.8135
# Epoch 140/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3412 - binary_accuracy: 0.8729 - val_loss: 0.4405 - val_binary_accuracy: 0.8135
# Epoch 141/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3395 - binary_accuracy: 0.8715 - val_loss: 0.4403 - val_binary_accuracy: 0.8135
# Epoch 142/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3419 - binary_accuracy: 0.8709 - val_loss: 0.4403 - val_binary_accuracy: 0.8135
# Epoch 143/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3395 - binary_accuracy: 0.8731 - val_loss: 0.4399 - val_binary_accuracy: 0.8135
# Epoch 144/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3376 - binary_accuracy: 0.8720 - val_loss: 0.4402 - val_binary_accuracy: 0.8135
# Epoch 145/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3395 - binary_accuracy: 0.8714 - val_loss: 0.4402 - val_binary_accuracy: 0.8135
# Epoch 146/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3404 - binary_accuracy: 0.8738 - val_loss: 0.4399 - val_binary_accuracy: 0.8135
# Epoch 147/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3425 - binary_accuracy: 0.8737 - val_loss: 0.4398 - val_binary_accuracy: 0.8135
# Epoch 148/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3442 - binary_accuracy: 0.8733 - val_loss: 0.4398 - val_binary_accuracy: 0.8135
# Epoch 149/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3424 - binary_accuracy: 0.8718 - val_loss: 0.4396 - val_binary_accuracy: 0.8135
# Epoch 150/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3411 - binary_accuracy: 0.8709 - val_loss: 0.4394 - val_binary_accuracy: 0.8135
# Epoch 151/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3384 - binary_accuracy: 0.8715 - val_loss: 0.4398 - val_binary_accuracy: 0.8135
# Epoch 152/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3403 - binary_accuracy: 0.8720 - val_loss: 0.4397 - val_binary_accuracy: 0.8135
# Epoch 153/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3393 - binary_accuracy: 0.8701 - val_loss: 0.4397 - val_binary_accuracy: 0.8135
# Epoch 154/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3413 - binary_accuracy: 0.8734 - val_loss: 0.4398 - val_binary_accuracy: 0.8135
# Epoch 155/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3417 - binary_accuracy: 0.8719 - val_loss: 0.4393 - val_binary_accuracy: 0.8135
# Epoch 156/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3407 - binary_accuracy: 0.8725 - val_loss: 0.4397 - val_binary_accuracy: 0.8135
# Epoch 157/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3398 - binary_accuracy: 0.8727 - val_loss: 0.4400 - val_binary_accuracy: 0.8135
# Epoch 158/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3398 - binary_accuracy: 0.8741 - val_loss: 0.4398 - val_binary_accuracy: 0.8135
# Epoch 159/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3389 - binary_accuracy: 0.8722 - val_loss: 0.4395 - val_binary_accuracy: 0.8128
# Epoch 160/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3412 - binary_accuracy: 0.8733 - val_loss: 0.4397 - val_binary_accuracy: 0.8135
# Epoch 161/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3385 - binary_accuracy: 0.8723 - val_loss: 0.4395 - val_binary_accuracy: 0.8128
# Epoch 162/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3404 - binary_accuracy: 0.8722 - val_loss: 0.4399 - val_binary_accuracy: 0.8135
# Epoch 163/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3374 - binary_accuracy: 0.8721 - val_loss: 0.4402 - val_binary_accuracy: 0.8128
# Epoch 164/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3394 - binary_accuracy: 0.8723 - val_loss: 0.4399 - val_binary_accuracy: 0.8128
# Epoch 165/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3408 - binary_accuracy: 0.8730 - val_loss: 0.4398 - val_binary_accuracy: 0.8128
# Epoch 166/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3380 - binary_accuracy: 0.8711 - val_loss: 0.4395 - val_binary_accuracy: 0.8128
# Epoch 167/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3374 - binary_accuracy: 0.8725 - val_loss: 0.4395 - val_binary_accuracy: 0.8135
# Epoch 168/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3410 - binary_accuracy: 0.8722 - val_loss: 0.4391 - val_binary_accuracy: 0.8135
# Epoch 169/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3363 - binary_accuracy: 0.8714 - val_loss: 0.4391 - val_binary_accuracy: 0.8135
# Epoch 170/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3399 - binary_accuracy: 0.8710 - val_loss: 0.4390 - val_binary_accuracy: 0.8135
# Epoch 171/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3386 - binary_accuracy: 0.8727 - val_loss: 0.4390 - val_binary_accuracy: 0.8135
# Epoch 172/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3350 - binary_accuracy: 0.8727 - val_loss: 0.4392 - val_binary_accuracy: 0.8135
# Epoch 173/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3399 - binary_accuracy: 0.8722 - val_loss: 0.4391 - val_binary_accuracy: 0.8135
# Epoch 174/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3380 - binary_accuracy: 0.8729 - val_loss: 0.4389 - val_binary_accuracy: 0.8135
# Epoch 175/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3398 - binary_accuracy: 0.8724 - val_loss: 0.4390 - val_binary_accuracy: 0.8135
# Epoch 176/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3411 - binary_accuracy: 0.8715 - val_loss: 0.4391 - val_binary_accuracy: 0.8135
# Epoch 177/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3364 - binary_accuracy: 0.8739 - val_loss: 0.4389 - val_binary_accuracy: 0.8135
# Epoch 178/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3381 - binary_accuracy: 0.8725 - val_loss: 0.4388 - val_binary_accuracy: 0.8135
# Epoch 179/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3392 - binary_accuracy: 0.8723 - val_loss: 0.4387 - val_binary_accuracy: 0.8135
# Epoch 180/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3369 - binary_accuracy: 0.8718 - val_loss: 0.4388 - val_binary_accuracy: 0.8135
# ('avg auroc: ', 0.7276880568821213)
# ('avg precision: ', 0.3371212121212121)
# ('avg recall: ', 0.6289752650176679)
# ('avg accuracy: ', 0.6990740740740741)
# ('avg specificity: ', 0.7152156224572823)
# ('avg f1: ', 0.43896424167694204)
# ('auroc: ', [0.7276880568821213])
# ('precision: ', [0.3371212121212121])
# ('recall: ', [0.6289752650176679])
# ('accuracy: ', [0.6990740740740741])
# ('specificity: ', [0.7152156224572823])
# ('f1: ', [0.43896424167694204])
# ('threshold: ', [0.15551978])
# CPU times: user 40min 42s, sys: 5min 54s, total: 46min 37s
# Wall time: 19min 46s

# %%
y_predict_t = model.predict_generator(mygenerator(X_train_list), steps=len(X_train_list))
y_predict_t = np.concatenate(y_predict_t)
y_true_t = np.concatenate(y_train_list)

f1_t, th_t = find_best_f1(y_predict_t, y_true_t)
precision_t, recall_t, accuracy_t, specificity_t = other_metrics(y_predict_t, y_true_t, th_t)

print('auroc: ', auroc(y_predict_t, y_true_t))
print('precision: ', precision_t)
print('recall: ', recall_t)
print('accuracy: ', accuracy_t)
print('specificity: ', specificity_t)
print('f1: ', f1_t);
print('threshold: ', th_t)
# Out:
# ('auroc: ', 0.7410817821285923)
# ('precision: ', 0.3654104979811575)
# ('recall: ', 0.5552147239263804)
# ('accuracy: ', 0.7405385049896441)
# ('specificity: ', 0.7823678744518809)
# ('f1: ', 0.4407467532467533)
# ('threshold: ', 0.22387436)

# %%
# from sklearn.calibration import calibration_curve
# # fraction_of_positives, mean_predicted_value = calibration_curve(y_true, y_predict, n_bins=10)
# fraction_of_positives, mean_predicted_value = calibration_curve(y_true, y_predict, normalize=True, n_bins=10)
# with open("exp_1_cal.csv", "w") as writeFile:
#     writer  = csv.writer(writeFile)
#     writer.writerows([fraction_of_positives, mean_predicted_value])

# plt.figure()
# plt.plot(mean_predicted_value, fraction_of_positives, 's-')
# plt.plot([0, 1], [0, 1], '--', color='gray')
# plt.show()

# %%
# import csv 
# fpr, tpr, thresholds = roc_curve(y_true, y_predict, pos_label=1)
# plot_roc_curve(fpr, tpr)
# with open("exp_1.csv", "w") as writeFile:
#     writer  = csv.writer(writeFile)
#     writer.writerows([fpr, tpr, [recall, 1-specificity]])

# %%
# %%time
seed(1)
set_random_seed(2)
auroc_list = []
precision_list = []
recall_list = []
accuracy_list = []
specificity_list = []
f1_list = []
th_list = []
for i in range(0,5):
    model = build_model(32, 0.5, 1, X_train_list[0][0].shape[0])
    history = fit_model(model, 180, X_train_list, y_train_list, X_test_list, y_test_list, verbose=1)
    y_predict = model.predict_generator(mygenerator(X_test_list), steps=len(X_test_list))
    y_predict = np.concatenate(y_predict)
    y_true = np.concatenate(y_test_list)
    auroc_list.append(auroc(y_predict, y_true))
    f1, th = find_best_f1(y_predict, y_true)
    f1_list.append(f1)
    th_list.append(th)
    precision, recall, accuracy, specificity = other_metrics(y_predict, y_true, th)
    precision_list.append(precision)
    recall_list.append(recall)
    accuracy_list.append(accuracy)
    specificity_list.append(specificity)
print('avg auroc: ', np.mean(auroc_list))
print('avg precision: ', np.mean(precision_list))
print('avg recall: ', np.mean(recall_list))
print('avg accuracy: ', np.mean(accuracy_list))
print('avg specificity: ', np.mean(specificity_list))
print('avg f1: ', np.mean(f1_list));
print('auroc: ', auroc_list)
print('precision: ', precision_list)
print('recall: ', recall_list)
print('accuracy: ', accuracy_list)
print('specificity: ', specificity_list)
print('f1: ', f1_list);
print('threshold: ', th_list)
# Out:
# Epoch 1/180
# 2193/2193 [==============================] - 19s 8ms/step - loss: 0.3786 - binary_accuracy: 0.8707 - val_loss: 0.4663 - val_binary_accuracy: 0.8128
# Epoch 2/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3628 - binary_accuracy: 0.8714 - val_loss: 0.4615 - val_binary_accuracy: 0.8128
# Epoch 3/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3610 - binary_accuracy: 0.8714 - val_loss: 0.4596 - val_binary_accuracy: 0.8128
# Epoch 4/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3583 - binary_accuracy: 0.8716 - val_loss: 0.4573 - val_binary_accuracy: 0.8128
# Epoch 5/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3580 - binary_accuracy: 0.8716 - val_loss: 0.4572 - val_binary_accuracy: 0.8128
# Epoch 6/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3550 - binary_accuracy: 0.8710 - val_loss: 0.4562 - val_binary_accuracy: 0.8128
# Epoch 7/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3519 - binary_accuracy: 0.8711 - val_loss: 0.4558 - val_binary_accuracy: 0.8128
# Epoch 8/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3550 - binary_accuracy: 0.8712 - val_loss: 0.4550 - val_binary_accuracy: 0.8128
# Epoch 9/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3551 - binary_accuracy: 0.8707 - val_loss: 0.4542 - val_binary_accuracy: 0.8128
# Epoch 10/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3529 - binary_accuracy: 0.8716 - val_loss: 0.4550 - val_binary_accuracy: 0.8128
# Epoch 11/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3531 - binary_accuracy: 0.8714 - val_loss: 0.4542 - val_binary_accuracy: 0.8128
# Epoch 12/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3521 - binary_accuracy: 0.8719 - val_loss: 0.4530 - val_binary_accuracy: 0.8128
# Epoch 13/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3535 - binary_accuracy: 0.8714 - val_loss: 0.4527 - val_binary_accuracy: 0.8128
# Epoch 14/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3520 - binary_accuracy: 0.8720 - val_loss: 0.4523 - val_binary_accuracy: 0.8128
# Epoch 15/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3494 - binary_accuracy: 0.8716 - val_loss: 0.4517 - val_binary_accuracy: 0.8128
# Epoch 16/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3499 - binary_accuracy: 0.8710 - val_loss: 0.4514 - val_binary_accuracy: 0.8128
# Epoch 17/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3531 - binary_accuracy: 0.8721 - val_loss: 0.4517 - val_binary_accuracy: 0.8128
# Epoch 18/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3503 - binary_accuracy: 0.8712 - val_loss: 0.4506 - val_binary_accuracy: 0.8128
# Epoch 19/180
# 2193/2193 [==============================] - 14s 6ms/step - loss: 0.3510 - binary_accuracy: 0.8716 - val_loss: 0.4502 - val_binary_accuracy: 0.8128
# Epoch 20/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3537 - binary_accuracy: 0.8717 - val_loss: 0.4496 - val_binary_accuracy: 0.8128
# Epoch 21/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3481 - binary_accuracy: 0.8721 - val_loss: 0.4495 - val_binary_accuracy: 0.8128
# Epoch 22/180
# 2193/2193 [==============================] - 14s 6ms/step - loss: 0.3507 - binary_accuracy: 0.8724 - val_loss: 0.4492 - val_binary_accuracy: 0.8128
# Epoch 23/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3504 - binary_accuracy: 0.8715 - val_loss: 0.4481 - val_binary_accuracy: 0.8128
# Epoch 24/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3502 - binary_accuracy: 0.8709 - val_loss: 0.4485 - val_binary_accuracy: 0.8128
# Epoch 25/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3498 - binary_accuracy: 0.8726 - val_loss: 0.4487 - val_binary_accuracy: 0.8128
# Epoch 26/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3483 - binary_accuracy: 0.8723 - val_loss: 0.4483 - val_binary_accuracy: 0.8128
# Epoch 27/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3483 - binary_accuracy: 0.8707 - val_loss: 0.4482 - val_binary_accuracy: 0.8128
# Epoch 28/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3481 - binary_accuracy: 0.8707 - val_loss: 0.4484 - val_binary_accuracy: 0.8128
# Epoch 29/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3469 - binary_accuracy: 0.8718 - val_loss: 0.4483 - val_binary_accuracy: 0.8128
# Epoch 30/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3460 - binary_accuracy: 0.8723 - val_loss: 0.4479 - val_binary_accuracy: 0.8128
# Epoch 31/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3507 - binary_accuracy: 0.8718 - val_loss: 0.4472 - val_binary_accuracy: 0.8128
# Epoch 32/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3487 - binary_accuracy: 0.8721 - val_loss: 0.4476 - val_binary_accuracy: 0.8128
# Epoch 33/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3480 - binary_accuracy: 0.8712 - val_loss: 0.4474 - val_binary_accuracy: 0.8128
# Epoch 34/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3479 - binary_accuracy: 0.8716 - val_loss: 0.4464 - val_binary_accuracy: 0.8128
# Epoch 35/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3475 - binary_accuracy: 0.8718 - val_loss: 0.4467 - val_binary_accuracy: 0.8128
# Epoch 36/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3475 - binary_accuracy: 0.8713 - val_loss: 0.4470 - val_binary_accuracy: 0.8128
# Epoch 37/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3462 - binary_accuracy: 0.8719 - val_loss: 0.4468 - val_binary_accuracy: 0.8128
# Epoch 38/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3461 - binary_accuracy: 0.8727 - val_loss: 0.4464 - val_binary_accuracy: 0.8128
# Epoch 39/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3464 - binary_accuracy: 0.8717 - val_loss: 0.4464 - val_binary_accuracy: 0.8128
# Epoch 40/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3463 - binary_accuracy: 0.8724 - val_loss: 0.4465 - val_binary_accuracy: 0.8128
# Epoch 41/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3471 - binary_accuracy: 0.8710 - val_loss: 0.4465 - val_binary_accuracy: 0.8128
# Epoch 42/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3502 - binary_accuracy: 0.8702 - val_loss: 0.4455 - val_binary_accuracy: 0.8128
# Epoch 43/180
# 2193/2193 [==============================] - 11s 5ms/step - loss: 0.3459 - binary_accuracy: 0.8716 - val_loss: 0.4452 - val_binary_accuracy: 0.8128
# Epoch 44/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3442 - binary_accuracy: 0.8720 - val_loss: 0.4454 - val_binary_accuracy: 0.8128
# Epoch 45/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3462 - binary_accuracy: 0.8724 - val_loss: 0.4448 - val_binary_accuracy: 0.8128
# Epoch 46/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3439 - binary_accuracy: 0.8721 - val_loss: 0.4452 - val_binary_accuracy: 0.8128
# Epoch 47/180
# 2193/2193 [==============================] - 11s 5ms/step - loss: 0.3459 - binary_accuracy: 0.8707 - val_loss: 0.4452 - val_binary_accuracy: 0.8128
# Epoch 48/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3464 - binary_accuracy: 0.8715 - val_loss: 0.4449 - val_binary_accuracy: 0.8122
# Epoch 49/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3440 - binary_accuracy: 0.8724 - val_loss: 0.4450 - val_binary_accuracy: 0.8128
# Epoch 50/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3470 - binary_accuracy: 0.8708 - val_loss: 0.4450 - val_binary_accuracy: 0.8128
# Epoch 51/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3457 - binary_accuracy: 0.8722 - val_loss: 0.4444 - val_binary_accuracy: 0.8128
# Epoch 52/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3453 - binary_accuracy: 0.8724 - val_loss: 0.4447 - val_binary_accuracy: 0.8128
# Epoch 53/180
# 2193/2193 [==============================] - 11s 5ms/step - loss: 0.3457 - binary_accuracy: 0.8723 - val_loss: 0.4442 - val_binary_accuracy: 0.8128
# Epoch 54/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3439 - binary_accuracy: 0.8734 - val_loss: 0.4441 - val_binary_accuracy: 0.8128
# Epoch 55/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3461 - binary_accuracy: 0.8715 - val_loss: 0.4443 - val_binary_accuracy: 0.8128
# Epoch 56/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3468 - binary_accuracy: 0.8716 - val_loss: 0.4439 - val_binary_accuracy: 0.8128
# Epoch 57/180
# 2193/2193 [==============================] - 11s 5ms/step - loss: 0.3444 - binary_accuracy: 0.8708 - val_loss: 0.4442 - val_binary_accuracy: 0.8128
# Epoch 58/180
# 2193/2193 [==============================] - 11s 5ms/step - loss: 0.3433 - binary_accuracy: 0.8721 - val_loss: 0.4444 - val_binary_accuracy: 0.8128
# Epoch 59/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3444 - binary_accuracy: 0.8729 - val_loss: 0.4443 - val_binary_accuracy: 0.8128
# Epoch 60/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3405 - binary_accuracy: 0.8728 - val_loss: 0.4443 - val_binary_accuracy: 0.8128
# Epoch 61/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3446 - binary_accuracy: 0.8723 - val_loss: 0.4442 - val_binary_accuracy: 0.8128
# Epoch 62/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3417 - binary_accuracy: 0.8726 - val_loss: 0.4441 - val_binary_accuracy: 0.8135
# Epoch 63/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3452 - binary_accuracy: 0.8706 - val_loss: 0.4439 - val_binary_accuracy: 0.8128
# Epoch 64/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3453 - binary_accuracy: 0.8729 - val_loss: 0.4437 - val_binary_accuracy: 0.8128
# Epoch 65/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3445 - binary_accuracy: 0.8730 - val_loss: 0.4434 - val_binary_accuracy: 0.8122
# Epoch 66/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3439 - binary_accuracy: 0.8712 - val_loss: 0.4432 - val_binary_accuracy: 0.8128
# Epoch 67/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3436 - binary_accuracy: 0.8716 - val_loss: 0.4430 - val_binary_accuracy: 0.8122
# Epoch 68/180
# 2193/2193 [==============================] - 9s 4ms/step - loss: 0.3439 - binary_accuracy: 0.8728 - val_loss: 0.4428 - val_binary_accuracy: 0.8128
# Epoch 69/180
# 2193/2193 [==============================] - 9s 4ms/step - loss: 0.3456 - binary_accuracy: 0.8714 - val_loss: 0.4425 - val_binary_accuracy: 0.8128
# Epoch 70/180
# 2193/2193 [==============================] - 9s 4ms/step - loss: 0.3428 - binary_accuracy: 0.8732 - val_loss: 0.4424 - val_binary_accuracy: 0.8128
# Epoch 71/180
# 2193/2193 [==============================] - 9s 4ms/step - loss: 0.3438 - binary_accuracy: 0.8703 - val_loss: 0.4420 - val_binary_accuracy: 0.8128
# Epoch 72/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3416 - binary_accuracy: 0.8720 - val_loss: 0.4422 - val_binary_accuracy: 0.8128
# Epoch 73/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3454 - binary_accuracy: 0.8717 - val_loss: 0.4420 - val_binary_accuracy: 0.8128
# Epoch 74/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3430 - binary_accuracy: 0.8726 - val_loss: 0.4419 - val_binary_accuracy: 0.8128
# Epoch 75/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3447 - binary_accuracy: 0.8730 - val_loss: 0.4420 - val_binary_accuracy: 0.8128
# Epoch 76/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3416 - binary_accuracy: 0.8725 - val_loss: 0.4418 - val_binary_accuracy: 0.8128
# Epoch 77/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3443 - binary_accuracy: 0.8717 - val_loss: 0.4415 - val_binary_accuracy: 0.8128
# Epoch 78/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3455 - binary_accuracy: 0.8718 - val_loss: 0.4418 - val_binary_accuracy: 0.8128
# Epoch 79/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3439 - binary_accuracy: 0.8724 - val_loss: 0.4414 - val_binary_accuracy: 0.8128
# Epoch 80/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3421 - binary_accuracy: 0.8724 - val_loss: 0.4414 - val_binary_accuracy: 0.8128
# Epoch 81/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3439 - binary_accuracy: 0.8732 - val_loss: 0.4417 - val_binary_accuracy: 0.8128
# Epoch 82/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3458 - binary_accuracy: 0.8706 - val_loss: 0.4418 - val_binary_accuracy: 0.8128
# Epoch 83/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3455 - binary_accuracy: 0.8715 - val_loss: 0.4412 - val_binary_accuracy: 0.8128
# Epoch 84/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3426 - binary_accuracy: 0.8718 - val_loss: 0.4415 - val_binary_accuracy: 0.8128
# Epoch 85/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3442 - binary_accuracy: 0.8719 - val_loss: 0.4419 - val_binary_accuracy: 0.8128
# Epoch 86/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3433 - binary_accuracy: 0.8713 - val_loss: 0.4420 - val_binary_accuracy: 0.8128
# Epoch 87/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3398 - binary_accuracy: 0.8738 - val_loss: 0.4420 - val_binary_accuracy: 0.8128
# Epoch 88/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3435 - binary_accuracy: 0.8715 - val_loss: 0.4416 - val_binary_accuracy: 0.8128
# Epoch 89/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3417 - binary_accuracy: 0.8711 - val_loss: 0.4418 - val_binary_accuracy: 0.8128
# Epoch 90/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3454 - binary_accuracy: 0.8711 - val_loss: 0.4412 - val_binary_accuracy: 0.8128
# Epoch 91/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3383 - binary_accuracy: 0.8722 - val_loss: 0.4411 - val_binary_accuracy: 0.8128
# Epoch 92/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3436 - binary_accuracy: 0.8730 - val_loss: 0.4415 - val_binary_accuracy: 0.8128
# Epoch 93/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3418 - binary_accuracy: 0.8728 - val_loss: 0.4408 - val_binary_accuracy: 0.8128
# Epoch 94/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3415 - binary_accuracy: 0.8738 - val_loss: 0.4410 - val_binary_accuracy: 0.8128
# Epoch 95/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3431 - binary_accuracy: 0.8725 - val_loss: 0.4412 - val_binary_accuracy: 0.8128
# Epoch 96/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3409 - binary_accuracy: 0.8718 - val_loss: 0.4409 - val_binary_accuracy: 0.8128
# Epoch 97/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3446 - binary_accuracy: 0.8727 - val_loss: 0.4406 - val_binary_accuracy: 0.8128
# Epoch 98/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3426 - binary_accuracy: 0.8720 - val_loss: 0.4404 - val_binary_accuracy: 0.8128
# Epoch 99/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3425 - binary_accuracy: 0.8721 - val_loss: 0.4404 - val_binary_accuracy: 0.8128
# Epoch 100/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3447 - binary_accuracy: 0.8722 - val_loss: 0.4401 - val_binary_accuracy: 0.8128
# Epoch 101/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3424 - binary_accuracy: 0.8716 - val_loss: 0.4404 - val_binary_accuracy: 0.8128
# Epoch 102/180
# 2193/2193 [==============================] - 8s 3ms/step - loss: 0.3388 - binary_accuracy: 0.8734 - val_loss: 0.4406 - val_binary_accuracy: 0.8128
# Epoch 103/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3428 - binary_accuracy: 0.8710 - val_loss: 0.4405 - val_binary_accuracy: 0.8128
# Epoch 104/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3383 - binary_accuracy: 0.8725 - val_loss: 0.4407 - val_binary_accuracy: 0.8128
# Epoch 105/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3425 - binary_accuracy: 0.8726 - val_loss: 0.4400 - val_binary_accuracy: 0.8128
# Epoch 106/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3422 - binary_accuracy: 0.8718 - val_loss: 0.4401 - val_binary_accuracy: 0.8128
# Epoch 107/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3411 - binary_accuracy: 0.8715 - val_loss: 0.4404 - val_binary_accuracy: 0.8128
# Epoch 108/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3438 - binary_accuracy: 0.8728 - val_loss: 0.4400 - val_binary_accuracy: 0.8128
# Epoch 109/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3434 - binary_accuracy: 0.8717 - val_loss: 0.4399 - val_binary_accuracy: 0.8128
# Epoch 110/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3418 - binary_accuracy: 0.8718 - val_loss: 0.4402 - val_binary_accuracy: 0.8128
# Epoch 111/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3424 - binary_accuracy: 0.8715 - val_loss: 0.4403 - val_binary_accuracy: 0.8128
# Epoch 112/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3419 - binary_accuracy: 0.8730 - val_loss: 0.4402 - val_binary_accuracy: 0.8128
# Epoch 113/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3412 - binary_accuracy: 0.8739 - val_loss: 0.4401 - val_binary_accuracy: 0.8128
# Epoch 114/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3399 - binary_accuracy: 0.8718 - val_loss: 0.4402 - val_binary_accuracy: 0.8128
# Epoch 115/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3421 - binary_accuracy: 0.8713 - val_loss: 0.4400 - val_binary_accuracy: 0.8128
# Epoch 116/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3401 - binary_accuracy: 0.8720 - val_loss: 0.4401 - val_binary_accuracy: 0.8128
# Epoch 117/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3418 - binary_accuracy: 0.8736 - val_loss: 0.4401 - val_binary_accuracy: 0.8128
# Epoch 118/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3433 - binary_accuracy: 0.8716 - val_loss: 0.4400 - val_binary_accuracy: 0.8128
# Epoch 119/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3390 - binary_accuracy: 0.8730 - val_loss: 0.4400 - val_binary_accuracy: 0.8135
# Epoch 120/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3427 - binary_accuracy: 0.8706 - val_loss: 0.4400 - val_binary_accuracy: 0.8135
# Epoch 121/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3418 - binary_accuracy: 0.8728 - val_loss: 0.4400 - val_binary_accuracy: 0.8135
# Epoch 122/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3405 - binary_accuracy: 0.8708 - val_loss: 0.4400 - val_binary_accuracy: 0.8135
# Epoch 123/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3368 - binary_accuracy: 0.8720 - val_loss: 0.4402 - val_binary_accuracy: 0.8135
# Epoch 124/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3408 - binary_accuracy: 0.8722 - val_loss: 0.4402 - val_binary_accuracy: 0.8135
# Epoch 125/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3388 - binary_accuracy: 0.8725 - val_loss: 0.4400 - val_binary_accuracy: 0.8135
# Epoch 126/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3379 - binary_accuracy: 0.8727 - val_loss: 0.4397 - val_binary_accuracy: 0.8135
# Epoch 127/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3427 - binary_accuracy: 0.8727 - val_loss: 0.4392 - val_binary_accuracy: 0.8135
# Epoch 128/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3401 - binary_accuracy: 0.8740 - val_loss: 0.4398 - val_binary_accuracy: 0.8135
# Epoch 129/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3383 - binary_accuracy: 0.8716 - val_loss: 0.4399 - val_binary_accuracy: 0.8135
# Epoch 130/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3397 - binary_accuracy: 0.8729 - val_loss: 0.4398 - val_binary_accuracy: 0.8135
# Epoch 131/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3438 - binary_accuracy: 0.8711 - val_loss: 0.4395 - val_binary_accuracy: 0.8135
# Epoch 132/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3417 - binary_accuracy: 0.8716 - val_loss: 0.4393 - val_binary_accuracy: 0.8135
# Epoch 133/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3429 - binary_accuracy: 0.8725 - val_loss: 0.4390 - val_binary_accuracy: 0.8135
# Epoch 134/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3392 - binary_accuracy: 0.8714 - val_loss: 0.4394 - val_binary_accuracy: 0.8135
# Epoch 135/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3430 - binary_accuracy: 0.8716 - val_loss: 0.4391 - val_binary_accuracy: 0.8135
# Epoch 136/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3411 - binary_accuracy: 0.8724 - val_loss: 0.4389 - val_binary_accuracy: 0.8135
# Epoch 137/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3393 - binary_accuracy: 0.8717 - val_loss: 0.4392 - val_binary_accuracy: 0.8135
# Epoch 138/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3414 - binary_accuracy: 0.8715 - val_loss: 0.4395 - val_binary_accuracy: 0.8135
# Epoch 139/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3403 - binary_accuracy: 0.8721 - val_loss: 0.4394 - val_binary_accuracy: 0.8135
# Epoch 140/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3410 - binary_accuracy: 0.8731 - val_loss: 0.4397 - val_binary_accuracy: 0.8135
# Epoch 141/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3393 - binary_accuracy: 0.8720 - val_loss: 0.4395 - val_binary_accuracy: 0.8128
# Epoch 142/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3419 - binary_accuracy: 0.8709 - val_loss: 0.4395 - val_binary_accuracy: 0.8135
# Epoch 143/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3392 - binary_accuracy: 0.8728 - val_loss: 0.4391 - val_binary_accuracy: 0.8128
# Epoch 144/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3374 - binary_accuracy: 0.8717 - val_loss: 0.4394 - val_binary_accuracy: 0.8128
# Epoch 145/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3394 - binary_accuracy: 0.8713 - val_loss: 0.4394 - val_binary_accuracy: 0.8128
# Epoch 146/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3403 - binary_accuracy: 0.8735 - val_loss: 0.4391 - val_binary_accuracy: 0.8128
# Epoch 147/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3421 - binary_accuracy: 0.8737 - val_loss: 0.4389 - val_binary_accuracy: 0.8128
# Epoch 148/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3443 - binary_accuracy: 0.8728 - val_loss: 0.4390 - val_binary_accuracy: 0.8128
# Epoch 149/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3425 - binary_accuracy: 0.8709 - val_loss: 0.4388 - val_binary_accuracy: 0.8128
# Epoch 150/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3408 - binary_accuracy: 0.8706 - val_loss: 0.4386 - val_binary_accuracy: 0.8128
# Epoch 151/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3384 - binary_accuracy: 0.8720 - val_loss: 0.4389 - val_binary_accuracy: 0.8128
# Epoch 152/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3400 - binary_accuracy: 0.8718 - val_loss: 0.4389 - val_binary_accuracy: 0.8128
# Epoch 153/180
# 2193/2193 [==============================] - 8s 3ms/step - loss: 0.3389 - binary_accuracy: 0.8698 - val_loss: 0.4387 - val_binary_accuracy: 0.8128
# Epoch 154/180
# 2193/2193 [==============================] - 8s 3ms/step - loss: 0.3409 - binary_accuracy: 0.8731 - val_loss: 0.4388 - val_binary_accuracy: 0.8128
# Epoch 155/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3415 - binary_accuracy: 0.8718 - val_loss: 0.4384 - val_binary_accuracy: 0.8128
# Epoch 156/180
# 2193/2193 [==============================] - 8s 3ms/step - loss: 0.3403 - binary_accuracy: 0.8729 - val_loss: 0.4388 - val_binary_accuracy: 0.8128
# Epoch 157/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3396 - binary_accuracy: 0.8724 - val_loss: 0.4391 - val_binary_accuracy: 0.8128
# Epoch 158/180
# 2193/2193 [==============================] - 8s 3ms/step - loss: 0.3396 - binary_accuracy: 0.8742 - val_loss: 0.4389 - val_binary_accuracy: 0.8128
# Epoch 159/180
# 2193/2193 [==============================] - 8s 3ms/step - loss: 0.3387 - binary_accuracy: 0.8726 - val_loss: 0.4386 - val_binary_accuracy: 0.8128
# Epoch 160/180
# 2193/2193 [==============================] - 8s 3ms/step - loss: 0.3409 - binary_accuracy: 0.8729 - val_loss: 0.4388 - val_binary_accuracy: 0.8128
# Epoch 161/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3385 - binary_accuracy: 0.8719 - val_loss: 0.4386 - val_binary_accuracy: 0.8128
# Epoch 162/180
# 2193/2193 [==============================] - 9s 4ms/step - loss: 0.3403 - binary_accuracy: 0.8717 - val_loss: 0.4390 - val_binary_accuracy: 0.8128
# Epoch 163/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3371 - binary_accuracy: 0.8721 - val_loss: 0.4393 - val_binary_accuracy: 0.8128
# Epoch 164/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3391 - binary_accuracy: 0.8716 - val_loss: 0.4390 - val_binary_accuracy: 0.8128
# Epoch 165/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3408 - binary_accuracy: 0.8734 - val_loss: 0.4389 - val_binary_accuracy: 0.8128
# Epoch 166/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3377 - binary_accuracy: 0.8714 - val_loss: 0.4387 - val_binary_accuracy: 0.8128
# Epoch 167/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3368 - binary_accuracy: 0.8731 - val_loss: 0.4386 - val_binary_accuracy: 0.8128
# Epoch 168/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3411 - binary_accuracy: 0.8720 - val_loss: 0.4382 - val_binary_accuracy: 0.8128
# Epoch 169/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3359 - binary_accuracy: 0.8718 - val_loss: 0.4383 - val_binary_accuracy: 0.8128
# Epoch 170/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3400 - binary_accuracy: 0.8715 - val_loss: 0.4382 - val_binary_accuracy: 0.8135
# Epoch 171/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3383 - binary_accuracy: 0.8729 - val_loss: 0.4381 - val_binary_accuracy: 0.8135
# Epoch 172/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3349 - binary_accuracy: 0.8718 - val_loss: 0.4383 - val_binary_accuracy: 0.8135
# Epoch 173/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3395 - binary_accuracy: 0.8727 - val_loss: 0.4383 - val_binary_accuracy: 0.8135
# Epoch 174/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3380 - binary_accuracy: 0.8728 - val_loss: 0.4380 - val_binary_accuracy: 0.8142
# Epoch 175/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3395 - binary_accuracy: 0.8720 - val_loss: 0.4381 - val_binary_accuracy: 0.8142
# Epoch 176/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3410 - binary_accuracy: 0.8715 - val_loss: 0.4382 - val_binary_accuracy: 0.8135
# Epoch 177/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3359 - binary_accuracy: 0.8743 - val_loss: 0.4380 - val_binary_accuracy: 0.8142
# Epoch 178/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3380 - binary_accuracy: 0.8724 - val_loss: 0.4379 - val_binary_accuracy: 0.8142
# Epoch 179/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3390 - binary_accuracy: 0.8726 - val_loss: 0.4378 - val_binary_accuracy: 0.8142
# Epoch 180/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3368 - binary_accuracy: 0.8720 - val_loss: 0.4379 - val_binary_accuracy: 0.8142
# Epoch 1/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3822 - binary_accuracy: 0.8711 - val_loss: 0.4719 - val_binary_accuracy: 0.8128
# Epoch 2/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3667 - binary_accuracy: 0.8711 - val_loss: 0.4656 - val_binary_accuracy: 0.8128
# Epoch 3/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3627 - binary_accuracy: 0.8711 - val_loss: 0.4633 - val_binary_accuracy: 0.8128
# Epoch 4/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3601 - binary_accuracy: 0.8712 - val_loss: 0.4620 - val_binary_accuracy: 0.8128
# Epoch 5/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3558 - binary_accuracy: 0.8711 - val_loss: 0.4616 - val_binary_accuracy: 0.8128
# Epoch 6/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3555 - binary_accuracy: 0.8710 - val_loss: 0.4596 - val_binary_accuracy: 0.8128
# Epoch 7/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3588 - binary_accuracy: 0.8711 - val_loss: 0.4594 - val_binary_accuracy: 0.8128
# Epoch 8/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3571 - binary_accuracy: 0.8712 - val_loss: 0.4587 - val_binary_accuracy: 0.8128
# Epoch 9/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3509 - binary_accuracy: 0.8712 - val_loss: 0.4586 - val_binary_accuracy: 0.8128
# Epoch 10/180
# 2193/2193 [==============================] - 8s 3ms/step - loss: 0.3512 - binary_accuracy: 0.8716 - val_loss: 0.4574 - val_binary_accuracy: 0.8128
# Epoch 11/180
# 2193/2193 [==============================] - 9s 4ms/step - loss: 0.3532 - binary_accuracy: 0.8712 - val_loss: 0.4570 - val_binary_accuracy: 0.8128
# Epoch 12/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3511 - binary_accuracy: 0.8713 - val_loss: 0.4554 - val_binary_accuracy: 0.8128
# Epoch 13/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3539 - binary_accuracy: 0.8709 - val_loss: 0.4552 - val_binary_accuracy: 0.8128
# Epoch 14/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3547 - binary_accuracy: 0.8713 - val_loss: 0.4539 - val_binary_accuracy: 0.8128
# Epoch 15/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3503 - binary_accuracy: 0.8710 - val_loss: 0.4542 - val_binary_accuracy: 0.8128
# Epoch 16/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3524 - binary_accuracy: 0.8712 - val_loss: 0.4527 - val_binary_accuracy: 0.8128
# Epoch 17/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3495 - binary_accuracy: 0.8713 - val_loss: 0.4524 - val_binary_accuracy: 0.8128
# Epoch 18/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3533 - binary_accuracy: 0.8710 - val_loss: 0.4516 - val_binary_accuracy: 0.8128
# Epoch 19/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3485 - binary_accuracy: 0.8712 - val_loss: 0.4521 - val_binary_accuracy: 0.8128
# Epoch 20/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3467 - binary_accuracy: 0.8715 - val_loss: 0.4513 - val_binary_accuracy: 0.8128
# Epoch 21/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3475 - binary_accuracy: 0.8722 - val_loss: 0.4513 - val_binary_accuracy: 0.8128
# Epoch 22/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3508 - binary_accuracy: 0.8723 - val_loss: 0.4503 - val_binary_accuracy: 0.8128
# Epoch 23/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3525 - binary_accuracy: 0.8716 - val_loss: 0.4504 - val_binary_accuracy: 0.8128
# Epoch 24/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3476 - binary_accuracy: 0.8717 - val_loss: 0.4502 - val_binary_accuracy: 0.8128
# Epoch 25/180
# 2193/2193 [==============================] - 8s 3ms/step - loss: 0.3475 - binary_accuracy: 0.8723 - val_loss: 0.4499 - val_binary_accuracy: 0.8128
# Epoch 26/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3479 - binary_accuracy: 0.8714 - val_loss: 0.4495 - val_binary_accuracy: 0.8128
# Epoch 27/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3478 - binary_accuracy: 0.8718 - val_loss: 0.4495 - val_binary_accuracy: 0.8128
# Epoch 28/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3489 - binary_accuracy: 0.8718 - val_loss: 0.4492 - val_binary_accuracy: 0.8128
# Epoch 29/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3466 - binary_accuracy: 0.8717 - val_loss: 0.4491 - val_binary_accuracy: 0.8128
# Epoch 30/180
# 2193/2193 [==============================] - 5s 3ms/step - loss: 0.3486 - binary_accuracy: 0.8718 - val_loss: 0.4480 - val_binary_accuracy: 0.8128
# Epoch 31/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3481 - binary_accuracy: 0.8723 - val_loss: 0.4483 - val_binary_accuracy: 0.8128
# Epoch 32/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3489 - binary_accuracy: 0.8720 - val_loss: 0.4483 - val_binary_accuracy: 0.8128
# Epoch 33/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3494 - binary_accuracy: 0.8716 - val_loss: 0.4479 - val_binary_accuracy: 0.8128
# Epoch 34/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3510 - binary_accuracy: 0.8713 - val_loss: 0.4470 - val_binary_accuracy: 0.8128
# Epoch 35/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3477 - binary_accuracy: 0.8711 - val_loss: 0.4471 - val_binary_accuracy: 0.8128
# Epoch 36/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3491 - binary_accuracy: 0.8719 - val_loss: 0.4464 - val_binary_accuracy: 0.8128
# Epoch 37/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3486 - binary_accuracy: 0.8724 - val_loss: 0.4462 - val_binary_accuracy: 0.8128
# Epoch 38/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3450 - binary_accuracy: 0.8721 - val_loss: 0.4467 - val_binary_accuracy: 0.8128
# Epoch 39/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3471 - binary_accuracy: 0.8731 - val_loss: 0.4463 - val_binary_accuracy: 0.8128
# Epoch 40/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3472 - binary_accuracy: 0.8719 - val_loss: 0.4460 - val_binary_accuracy: 0.8128
# Epoch 41/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3481 - binary_accuracy: 0.8712 - val_loss: 0.4461 - val_binary_accuracy: 0.8128
# Epoch 42/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3476 - binary_accuracy: 0.8723 - val_loss: 0.4459 - val_binary_accuracy: 0.8128
# Epoch 43/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3456 - binary_accuracy: 0.8718 - val_loss: 0.4461 - val_binary_accuracy: 0.8128
# Epoch 44/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3487 - binary_accuracy: 0.8724 - val_loss: 0.4455 - val_binary_accuracy: 0.8128
# Epoch 45/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3482 - binary_accuracy: 0.8719 - val_loss: 0.4459 - val_binary_accuracy: 0.8128
# Epoch 46/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3481 - binary_accuracy: 0.8715 - val_loss: 0.4458 - val_binary_accuracy: 0.8128
# Epoch 47/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3493 - binary_accuracy: 0.8722 - val_loss: 0.4453 - val_binary_accuracy: 0.8128
# Epoch 48/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3451 - binary_accuracy: 0.8724 - val_loss: 0.4448 - val_binary_accuracy: 0.8128
# Epoch 49/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3451 - binary_accuracy: 0.8716 - val_loss: 0.4448 - val_binary_accuracy: 0.8128
# Epoch 50/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3496 - binary_accuracy: 0.8720 - val_loss: 0.4444 - val_binary_accuracy: 0.8128
# Epoch 51/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3456 - binary_accuracy: 0.8715 - val_loss: 0.4446 - val_binary_accuracy: 0.8128
# Epoch 52/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3476 - binary_accuracy: 0.8719 - val_loss: 0.4446 - val_binary_accuracy: 0.8128
# Epoch 53/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3463 - binary_accuracy: 0.8719 - val_loss: 0.4444 - val_binary_accuracy: 0.8128
# Epoch 54/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3469 - binary_accuracy: 0.8724 - val_loss: 0.4443 - val_binary_accuracy: 0.8128
# Epoch 55/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3458 - binary_accuracy: 0.8709 - val_loss: 0.4443 - val_binary_accuracy: 0.8128
# Epoch 56/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3447 - binary_accuracy: 0.8712 - val_loss: 0.4442 - val_binary_accuracy: 0.8128
# Epoch 57/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3446 - binary_accuracy: 0.8722 - val_loss: 0.4439 - val_binary_accuracy: 0.8122
# Epoch 58/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3455 - binary_accuracy: 0.8717 - val_loss: 0.4442 - val_binary_accuracy: 0.8122
# Epoch 59/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3475 - binary_accuracy: 0.8722 - val_loss: 0.4439 - val_binary_accuracy: 0.8128
# Epoch 60/180
# 2193/2193 [==============================] - 5s 2ms/step - loss: 0.3465 - binary_accuracy: 0.8729 - val_loss: 0.4438 - val_binary_accuracy: 0.8128
# Epoch 61/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3401 - binary_accuracy: 0.8720 - val_loss: 0.4444 - val_binary_accuracy: 0.8128
# Epoch 62/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3465 - binary_accuracy: 0.8729 - val_loss: 0.4442 - val_binary_accuracy: 0.8128
# Epoch 63/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3453 - binary_accuracy: 0.8706 - val_loss: 0.4439 - val_binary_accuracy: 0.8122
# Epoch 64/180
# 2193/2193 [==============================] - 9s 4ms/step - loss: 0.3467 - binary_accuracy: 0.8716 - val_loss: 0.4437 - val_binary_accuracy: 0.8122
# Epoch 65/180
# 2193/2193 [==============================] - 9s 4ms/step - loss: 0.3460 - binary_accuracy: 0.8715 - val_loss: 0.4433 - val_binary_accuracy: 0.8122
# Epoch 66/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3472 - binary_accuracy: 0.8719 - val_loss: 0.4430 - val_binary_accuracy: 0.8122
# Epoch 67/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3433 - binary_accuracy: 0.8730 - val_loss: 0.4435 - val_binary_accuracy: 0.8122
# Epoch 68/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3467 - binary_accuracy: 0.8721 - val_loss: 0.4430 - val_binary_accuracy: 0.8122
# Epoch 69/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3461 - binary_accuracy: 0.8730 - val_loss: 0.4430 - val_binary_accuracy: 0.8122
# Epoch 70/180
# 2193/2193 [==============================] - 8s 4ms/step - loss: 0.3455 - binary_accuracy: 0.8718 - val_loss: 0.4432 - val_binary_accuracy: 0.8122
# Epoch 71/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3427 - binary_accuracy: 0.8716 - val_loss: 0.4432 - val_binary_accuracy: 0.8122
# Epoch 72/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3453 - binary_accuracy: 0.8735 - val_loss: 0.4429 - val_binary_accuracy: 0.8122
# Epoch 73/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3435 - binary_accuracy: 0.8716 - val_loss: 0.4424 - val_binary_accuracy: 0.8122
# Epoch 74/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3444 - binary_accuracy: 0.8718 - val_loss: 0.4428 - val_binary_accuracy: 0.8122
# Epoch 75/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3454 - binary_accuracy: 0.8721 - val_loss: 0.4426 - val_binary_accuracy: 0.8122
# Epoch 76/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3448 - binary_accuracy: 0.8720 - val_loss: 0.4425 - val_binary_accuracy: 0.8122
# Epoch 77/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3469 - binary_accuracy: 0.8708 - val_loss: 0.4421 - val_binary_accuracy: 0.8122
# Epoch 78/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3454 - binary_accuracy: 0.8716 - val_loss: 0.4420 - val_binary_accuracy: 0.8122
# Epoch 79/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3441 - binary_accuracy: 0.8725 - val_loss: 0.4419 - val_binary_accuracy: 0.8122
# Epoch 80/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3432 - binary_accuracy: 0.8715 - val_loss: 0.4418 - val_binary_accuracy: 0.8122
# Epoch 81/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3420 - binary_accuracy: 0.8730 - val_loss: 0.4419 - val_binary_accuracy: 0.8122
# Epoch 82/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3441 - binary_accuracy: 0.8719 - val_loss: 0.4420 - val_binary_accuracy: 0.8128
# Epoch 83/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3413 - binary_accuracy: 0.8739 - val_loss: 0.4420 - val_binary_accuracy: 0.8122
# Epoch 84/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3439 - binary_accuracy: 0.8708 - val_loss: 0.4419 - val_binary_accuracy: 0.8122
# Epoch 85/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3463 - binary_accuracy: 0.8721 - val_loss: 0.4413 - val_binary_accuracy: 0.8128
# Epoch 86/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3431 - binary_accuracy: 0.8718 - val_loss: 0.4415 - val_binary_accuracy: 0.8128
# Epoch 87/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3454 - binary_accuracy: 0.8720 - val_loss: 0.4415 - val_binary_accuracy: 0.8128
# Epoch 88/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3440 - binary_accuracy: 0.8726 - val_loss: 0.4415 - val_binary_accuracy: 0.8128
# Epoch 89/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3441 - binary_accuracy: 0.8716 - val_loss: 0.4415 - val_binary_accuracy: 0.8128
# Epoch 90/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3404 - binary_accuracy: 0.8719 - val_loss: 0.4416 - val_binary_accuracy: 0.8128
# Epoch 91/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3425 - binary_accuracy: 0.8716 - val_loss: 0.4412 - val_binary_accuracy: 0.8128
# Epoch 92/180
# 2193/2193 [==============================] - 14s 6ms/step - loss: 0.3419 - binary_accuracy: 0.8721 - val_loss: 0.4413 - val_binary_accuracy: 0.8128
# Epoch 93/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3430 - binary_accuracy: 0.8729 - val_loss: 0.4411 - val_binary_accuracy: 0.8128
# Epoch 94/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3444 - binary_accuracy: 0.8723 - val_loss: 0.4408 - val_binary_accuracy: 0.8128
# Epoch 95/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3428 - binary_accuracy: 0.8732 - val_loss: 0.4408 - val_binary_accuracy: 0.8128
# Epoch 96/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3458 - binary_accuracy: 0.8716 - val_loss: 0.4406 - val_binary_accuracy: 0.8128
# Epoch 97/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3449 - binary_accuracy: 0.8717 - val_loss: 0.4405 - val_binary_accuracy: 0.8128
# Epoch 98/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3437 - binary_accuracy: 0.8729 - val_loss: 0.4407 - val_binary_accuracy: 0.8122
# Epoch 99/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3408 - binary_accuracy: 0.8722 - val_loss: 0.4408 - val_binary_accuracy: 0.8122
# Epoch 100/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3446 - binary_accuracy: 0.8724 - val_loss: 0.4408 - val_binary_accuracy: 0.8122
# Epoch 101/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3434 - binary_accuracy: 0.8728 - val_loss: 0.4408 - val_binary_accuracy: 0.8122
# Epoch 102/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3442 - binary_accuracy: 0.8729 - val_loss: 0.4410 - val_binary_accuracy: 0.8128
# Epoch 103/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3397 - binary_accuracy: 0.8716 - val_loss: 0.4406 - val_binary_accuracy: 0.8122
# Epoch 104/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3461 - binary_accuracy: 0.8705 - val_loss: 0.4407 - val_binary_accuracy: 0.8122
# Epoch 105/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3438 - binary_accuracy: 0.8720 - val_loss: 0.4406 - val_binary_accuracy: 0.8122
# Epoch 106/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3445 - binary_accuracy: 0.8723 - val_loss: 0.4406 - val_binary_accuracy: 0.8122
# Epoch 107/180
# 2193/2193 [==============================] - 11s 5ms/step - loss: 0.3419 - binary_accuracy: 0.8716 - val_loss: 0.4407 - val_binary_accuracy: 0.8122
# Epoch 108/180
# 2193/2193 [==============================] - 11s 5ms/step - loss: 0.3422 - binary_accuracy: 0.8713 - val_loss: 0.4403 - val_binary_accuracy: 0.8122
# Epoch 109/180
# 2193/2193 [==============================] - 12s 5ms/step - loss: 0.3424 - binary_accuracy: 0.8738 - val_loss: 0.4400 - val_binary_accuracy: 0.8122
# Epoch 110/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3411 - binary_accuracy: 0.8727 - val_loss: 0.4399 - val_binary_accuracy: 0.8122
# Epoch 111/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3415 - binary_accuracy: 0.8723 - val_loss: 0.4402 - val_binary_accuracy: 0.8122
# Epoch 112/180
# 2193/2193 [==============================] - 12s 6ms/step - loss: 0.3419 - binary_accuracy: 0.8722 - val_loss: 0.4397 - val_binary_accuracy: 0.8128
# Epoch 113/180
# 2193/2193 [==============================] - 13s 6ms/step - loss: 0.3448 - binary_accuracy: 0.8715 - val_loss: 0.4397 - val_binary_accuracy: 0.8128
# Epoch 114/180
# 2193/2193 [==============================] - 11s 5ms/step - loss: 0.3459 - binary_accuracy: 0.8718 - val_loss: 0.4401 - val_binary_accuracy: 0.8122
# Epoch 115/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3416 - binary_accuracy: 0.8709 - val_loss: 0.4402 - val_binary_accuracy: 0.8122
# Epoch 116/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3430 - binary_accuracy: 0.8719 - val_loss: 0.4401 - val_binary_accuracy: 0.8122
# Epoch 117/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3430 - binary_accuracy: 0.8710 - val_loss: 0.4400 - val_binary_accuracy: 0.8122
# Epoch 118/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3445 - binary_accuracy: 0.8739 - val_loss: 0.4400 - val_binary_accuracy: 0.8122
# Epoch 119/180
# ...
# Epoch 89/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3440 - binary_accuracy: 0.8716 - val_loss: 0.4397 - val_binary_accuracy: 0.8135
# Epoch 90/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3438 - binary_accuracy: 0.8728 - val_loss: 0.4394 - val_binary_accuracy: 0.8135
# Epoch 91/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3424 - binary_accuracy: 0.8731 - val_loss: 0.4396 - val_binary_accuracy: 0.8135
# Epoch 92/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3470 - binary_accuracy: 0.8720 - val_loss: 0.4392 - val_binary_accuracy: 0.8135
# Epoch 93/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3420 - binary_accuracy: 0.8721 - val_loss: 0.4394 - val_binary_accuracy: 0.8135
# Epoch 94/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3455 - binary_accuracy: 0.8714 - val_loss: 0.4393 - val_binary_accuracy: 0.8135
# Epoch 95/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3439 - binary_accuracy: 0.8729 - val_loss: 0.4391 - val_binary_accuracy: 0.8135
# Epoch 96/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3429 - binary_accuracy: 0.8724 - val_loss: 0.4389 - val_binary_accuracy: 0.8135
# Epoch 97/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3417 - binary_accuracy: 0.8719 - val_loss: 0.4390 - val_binary_accuracy: 0.8135
# Epoch 98/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3454 - binary_accuracy: 0.8728 - val_loss: 0.4387 - val_binary_accuracy: 0.8135
# Epoch 99/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3417 - binary_accuracy: 0.8720 - val_loss: 0.4388 - val_binary_accuracy: 0.8135
# Epoch 100/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3423 - binary_accuracy: 0.8713 - val_loss: 0.4390 - val_binary_accuracy: 0.8135
# Epoch 101/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3449 - binary_accuracy: 0.8718 - val_loss: 0.4389 - val_binary_accuracy: 0.8135
# Epoch 102/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3439 - binary_accuracy: 0.8728 - val_loss: 0.4385 - val_binary_accuracy: 0.8135
# Epoch 103/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3403 - binary_accuracy: 0.8726 - val_loss: 0.4387 - val_binary_accuracy: 0.8135
# Epoch 104/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3392 - binary_accuracy: 0.8727 - val_loss: 0.4386 - val_binary_accuracy: 0.8135
# Epoch 105/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3419 - binary_accuracy: 0.8714 - val_loss: 0.4388 - val_binary_accuracy: 0.8135
# Epoch 106/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3416 - binary_accuracy: 0.8715 - val_loss: 0.4385 - val_binary_accuracy: 0.8135
# Epoch 107/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3457 - binary_accuracy: 0.8717 - val_loss: 0.4382 - val_binary_accuracy: 0.8135
# Epoch 108/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3403 - binary_accuracy: 0.8725 - val_loss: 0.4382 - val_binary_accuracy: 0.8135
# Epoch 109/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3448 - binary_accuracy: 0.8724 - val_loss: 0.4382 - val_binary_accuracy: 0.8135
# Epoch 110/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3418 - binary_accuracy: 0.8726 - val_loss: 0.4384 - val_binary_accuracy: 0.8135
# Epoch 111/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3399 - binary_accuracy: 0.8716 - val_loss: 0.4384 - val_binary_accuracy: 0.8135
# Epoch 112/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3412 - binary_accuracy: 0.8728 - val_loss: 0.4382 - val_binary_accuracy: 0.8135
# Epoch 113/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3426 - binary_accuracy: 0.8709 - val_loss: 0.4382 - val_binary_accuracy: 0.8135
# Epoch 114/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3418 - binary_accuracy: 0.8726 - val_loss: 0.4381 - val_binary_accuracy: 0.8128
# Epoch 115/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3386 - binary_accuracy: 0.8735 - val_loss: 0.4380 - val_binary_accuracy: 0.8128
# Epoch 116/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3408 - binary_accuracy: 0.8713 - val_loss: 0.4381 - val_binary_accuracy: 0.8128
# Epoch 117/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3400 - binary_accuracy: 0.8734 - val_loss: 0.4384 - val_binary_accuracy: 0.8128
# Epoch 118/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3412 - binary_accuracy: 0.8722 - val_loss: 0.4381 - val_binary_accuracy: 0.8128
# Epoch 119/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3383 - binary_accuracy: 0.8723 - val_loss: 0.4380 - val_binary_accuracy: 0.8135
# Epoch 120/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3407 - binary_accuracy: 0.8720 - val_loss: 0.4379 - val_binary_accuracy: 0.8135
# Epoch 121/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3424 - binary_accuracy: 0.8716 - val_loss: 0.4379 - val_binary_accuracy: 0.8128
# Epoch 122/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3458 - binary_accuracy: 0.8720 - val_loss: 0.4374 - val_binary_accuracy: 0.8128
# Epoch 123/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3427 - binary_accuracy: 0.8716 - val_loss: 0.4378 - val_binary_accuracy: 0.8128
# Epoch 124/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3426 - binary_accuracy: 0.8722 - val_loss: 0.4377 - val_binary_accuracy: 0.8128
# Epoch 125/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3449 - binary_accuracy: 0.8726 - val_loss: 0.4377 - val_binary_accuracy: 0.8128
# Epoch 126/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3419 - binary_accuracy: 0.8732 - val_loss: 0.4377 - val_binary_accuracy: 0.8128
# Epoch 127/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3411 - binary_accuracy: 0.8719 - val_loss: 0.4379 - val_binary_accuracy: 0.8128
# Epoch 128/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3433 - binary_accuracy: 0.8731 - val_loss: 0.4375 - val_binary_accuracy: 0.8128
# Epoch 129/180
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3400 - binary_accuracy: 0.8741 - val_loss: 0.4372 - val_binary_accuracy: 0.8128
# Epoch 130/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3420 - binary_accuracy: 0.8721 - val_loss: 0.4374 - val_binary_accuracy: 0.8128
# Epoch 131/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3421 - binary_accuracy: 0.8730 - val_loss: 0.4375 - val_binary_accuracy: 0.8128
# Epoch 132/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3419 - binary_accuracy: 0.8738 - val_loss: 0.4374 - val_binary_accuracy: 0.8128
# Epoch 133/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3430 - binary_accuracy: 0.8728 - val_loss: 0.4372 - val_binary_accuracy: 0.8128
# Epoch 134/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3450 - binary_accuracy: 0.8721 - val_loss: 0.4371 - val_binary_accuracy: 0.8128
# Epoch 135/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3407 - binary_accuracy: 0.8743 - val_loss: 0.4366 - val_binary_accuracy: 0.8128
# Epoch 136/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3409 - binary_accuracy: 0.8720 - val_loss: 0.4368 - val_binary_accuracy: 0.8128
# Epoch 137/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3441 - binary_accuracy: 0.8714 - val_loss: 0.4370 - val_binary_accuracy: 0.8128
# Epoch 138/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3436 - binary_accuracy: 0.8726 - val_loss: 0.4370 - val_binary_accuracy: 0.8128
# Epoch 139/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3406 - binary_accuracy: 0.8719 - val_loss: 0.4373 - val_binary_accuracy: 0.8128
# Epoch 140/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3390 - binary_accuracy: 0.8725 - val_loss: 0.4372 - val_binary_accuracy: 0.8128
# Epoch 141/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3414 - binary_accuracy: 0.8729 - val_loss: 0.4372 - val_binary_accuracy: 0.8128
# Epoch 142/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3382 - binary_accuracy: 0.8728 - val_loss: 0.4371 - val_binary_accuracy: 0.8128
# Epoch 143/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3427 - binary_accuracy: 0.8706 - val_loss: 0.4370 - val_binary_accuracy: 0.8128
# Epoch 144/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3403 - binary_accuracy: 0.8724 - val_loss: 0.4369 - val_binary_accuracy: 0.8128
# Epoch 145/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3381 - binary_accuracy: 0.8728 - val_loss: 0.4369 - val_binary_accuracy: 0.8122
# Epoch 146/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3389 - binary_accuracy: 0.8726 - val_loss: 0.4368 - val_binary_accuracy: 0.8122
# Epoch 147/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3411 - binary_accuracy: 0.8737 - val_loss: 0.4368 - val_binary_accuracy: 0.8122
# Epoch 148/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3418 - binary_accuracy: 0.8736 - val_loss: 0.4368 - val_binary_accuracy: 0.8122
# Epoch 149/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3416 - binary_accuracy: 0.8736 - val_loss: 0.4366 - val_binary_accuracy: 0.8122
# Epoch 150/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3416 - binary_accuracy: 0.8727 - val_loss: 0.4362 - val_binary_accuracy: 0.8122
# Epoch 151/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3396 - binary_accuracy: 0.8720 - val_loss: 0.4367 - val_binary_accuracy: 0.8122
# Epoch 152/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3401 - binary_accuracy: 0.8716 - val_loss: 0.4367 - val_binary_accuracy: 0.8122
# Epoch 153/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3435 - binary_accuracy: 0.8711 - val_loss: 0.4366 - val_binary_accuracy: 0.8122
# Epoch 154/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3408 - binary_accuracy: 0.8730 - val_loss: 0.4365 - val_binary_accuracy: 0.8122
# Epoch 155/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3417 - binary_accuracy: 0.8713 - val_loss: 0.4366 - val_binary_accuracy: 0.8122
# Epoch 156/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3440 - binary_accuracy: 0.8730 - val_loss: 0.4364 - val_binary_accuracy: 0.8122
# Epoch 157/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3411 - binary_accuracy: 0.8724 - val_loss: 0.4363 - val_binary_accuracy: 0.8122
# Epoch 158/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3436 - binary_accuracy: 0.8719 - val_loss: 0.4366 - val_binary_accuracy: 0.8122
# Epoch 159/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3389 - binary_accuracy: 0.8713 - val_loss: 0.4365 - val_binary_accuracy: 0.8122
# Epoch 160/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3370 - binary_accuracy: 0.8725 - val_loss: 0.4368 - val_binary_accuracy: 0.8122
# Epoch 161/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3423 - binary_accuracy: 0.8722 - val_loss: 0.4364 - val_binary_accuracy: 0.8122
# Epoch 162/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3428 - binary_accuracy: 0.8720 - val_loss: 0.4366 - val_binary_accuracy: 0.8122
# Epoch 163/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3366 - binary_accuracy: 0.8740 - val_loss: 0.4365 - val_binary_accuracy: 0.8122
# Epoch 164/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3397 - binary_accuracy: 0.8714 - val_loss: 0.4368 - val_binary_accuracy: 0.8122
# Epoch 165/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3389 - binary_accuracy: 0.8726 - val_loss: 0.4367 - val_binary_accuracy: 0.8122
# Epoch 166/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3415 - binary_accuracy: 0.8725 - val_loss: 0.4368 - val_binary_accuracy: 0.8122
# Epoch 167/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3416 - binary_accuracy: 0.8729 - val_loss: 0.4366 - val_binary_accuracy: 0.8122
# Epoch 168/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3366 - binary_accuracy: 0.8732 - val_loss: 0.4368 - val_binary_accuracy: 0.8122
# Epoch 169/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3400 - binary_accuracy: 0.8724 - val_loss: 0.4367 - val_binary_accuracy: 0.8122
# Epoch 170/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3385 - binary_accuracy: 0.8718 - val_loss: 0.4363 - val_binary_accuracy: 0.8122
# Epoch 171/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3394 - binary_accuracy: 0.8726 - val_loss: 0.4366 - val_binary_accuracy: 0.8122
# Epoch 172/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3387 - binary_accuracy: 0.8730 - val_loss: 0.4368 - val_binary_accuracy: 0.8122
# Epoch 173/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3372 - binary_accuracy: 0.8719 - val_loss: 0.4367 - val_binary_accuracy: 0.8122
# Epoch 174/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3373 - binary_accuracy: 0.8721 - val_loss: 0.4366 - val_binary_accuracy: 0.8122
# Epoch 175/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3417 - binary_accuracy: 0.8722 - val_loss: 0.4367 - val_binary_accuracy: 0.8122
# Epoch 176/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3423 - binary_accuracy: 0.8722 - val_loss: 0.4365 - val_binary_accuracy: 0.8122
# Epoch 177/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3380 - binary_accuracy: 0.8719 - val_loss: 0.4366 - val_binary_accuracy: 0.8122
# Epoch 178/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3360 - binary_accuracy: 0.8717 - val_loss: 0.4366 - val_binary_accuracy: 0.8122
# Epoch 179/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3362 - binary_accuracy: 0.8717 - val_loss: 0.4368 - val_binary_accuracy: 0.8122
# Epoch 180/180
# 2193/2193 [==============================] - 6s 3ms/step - loss: 0.3415 - binary_accuracy: 0.8716 - val_loss: 0.4368 - val_binary_accuracy: 0.8122
# ('avg auroc: ', 0.7266380492629534)
# ('avg precision: ', 0.3472347295691086)
# ('avg recall: ', 0.6070671378091872)
# ('avg accuracy: ', 0.7116402116402117)
# ('avg specificity: ', 0.735720097640358)
# ('avg f1: ', 0.4408103615995471)
# ('auroc: ', [0.7288007429407689, 0.7233753202206972, 0.7251349167785583, 0.728343592854658, 0.7275356735200844])
# ('precision: ', [0.3416988416988417, 0.3302238805970149, 0.3401869158878505, 0.35208333333333336, 0.3719806763285024])
# ('recall: ', [0.6254416961130742, 0.6254416961130742, 0.6431095406360424, 0.5971731448763251, 0.5441696113074205])
# ('accuracy: ', [0.7043650793650794, 0.6924603174603174, 0.6997354497354498, 0.718915343915344, 0.7427248677248677])
# ('specificity: ', [0.7225386493083807, 0.7078925956061839, 0.7127746135069162, 0.7469487388120423, 0.7884458909682669])
# ('f1: ', [0.44194756554307113, 0.43223443223443225, 0.4449877750611248, 0.44298820445609444, 0.44189383070301286])
# ('threshold: ', [0.15807657, 0.15955122, 0.16049157, 0.16895026, 0.18958326])
# CPU times: user 3h 23min 47s, sys: 24min 46s, total: 3h 48min 34s
# Wall time: 2h 13s

# %% [markdown]
# unit: 8	epoch: 50	auroc_mean: 0.699555	auroc_std: 0.019156
# unit: 8	epoch: 60	auroc_mean: 0.700691	auroc_std: 0.018938
# unit: 8	epoch: 70	auroc_mean: 0.701370	auroc_std: 0.018729
# unit: 8	epoch: 100	auroc_mean: 0.702887	auroc_std: 0.018197
# unit: 8	epoch: 125	auroc_mean: 0.703563	auroc_std: 0.018108
# unit: 8	epoch: 150	auroc_mean: 0.703994	auroc_std: 0.018072
# unit: 8	epoch: 200	auroc_mean: 0.704332	auroc_std: 0.017631
# unit: 8	epoch: 300	auroc_mean: 0.704859	auroc_std: 0.017847
#
# unit: 8 	epoch: 100	auroc_mean: 0.702887	auroc_std: 0.018197
# unit: 16	epoch: 100	auroc_mean: 0.706576	auroc_std: 0.018529
# unit: 25	epoch: 100	auroc_mean: 0.705890	auroc_std: 0.018846
# unit: 30	epoch: 100	auroc_mean: 0.706146	auroc_std: 0.019411
# unit: 32	epoch: 100	auroc_mean: 0.707448	auroc_std: 0.019337
# unit: 40	epoch: 100	auroc_mean: 0.706949	auroc_std: 0.018761
# unit: 50	epoch: 100	auroc_mean: 0.706192	auroc_std: 0.020768
#
# unit: 32	epoch: 65	auroc_mean: 0.706663	auroc_std: 0.018844
# unit: 32	epoch: 70	auroc_mean: 0.706855	auroc_std: 0.018997
# unit: 32	epoch: 85	auroc_mean: 0.707206	auroc_std: 0.019241
# unit: 32	epoch: 100	auroc_mean: 0.707448	auroc_std: 0.019337
# unit: 32	epoch: 150	auroc_mean: 0.708563	auroc_std: 0.019562
# unit: 32	epoch: 170	auroc_mean: 0.708822	auroc_std: 0.019401
# unit: 32	epoch: 180	auroc_mean: 0.709108	auroc_std: 0.019497 *
# unit: 32	epoch: 190	auroc_mean: 0.709048	auroc_std: 0.019752
# unit: 32	epoch: 200	auroc_mean: 0.708935	auroc_std: 0.019949
# unit: 32	epoch: 210	auroc_mean: 0.708586	auroc_std: 0.019831
# unit: 32	epoch: 250	auroc_mean: 0.708529	auroc_std: 0.020297
#
# unit: 50	epoch: 80	auroc_mean: 0.705207	auroc_std: 0.020670
# unit: 50	epoch: 100	auroc_mean: 0.706192	auroc_std: 0.020768

# %%
# %%time
# # K-Fold Cross Validation
# ratio = 0.1
# result = []
# pdic = [(32, [90], [0.5])]
# for unit, epoch_list, ratio_list in pdic:
#     for epoch in epoch_list:
#         for ratio in ratio_list:
#             auroc_list = kfold_validation(unit, ratio, epoch, X_train_transformed, y_train, 'patient-id', verbose=1)
#             result.append((unit, epoch, auroc_list))
#             print("unit: %d\tepoch: %d\tauroc_mean: %f\tauroc_std: %f"  % (unit, epoch, np.mean(auroc_list), np.std(auroc_list)))

# %% [markdown]
# #learning rate 0.006
# unit: 32	epoch: 250	auroc_mean: 0.707665	auroc_std: 0.019160
# unit: 32	epoch: 270	auroc_mean: 0.707776	auroc_std: 0.019195
# unit: 50	epoch: 200	auroc_mean: 0.705745	auroc_std: 0.020189
# unit: 70	epoch: 200	auroc_mean: 0.708010	auroc_std: 0.019193
# unit: 100	epoch: 200	auroc_mean: 0.706446	auroc_std: 0.019270
